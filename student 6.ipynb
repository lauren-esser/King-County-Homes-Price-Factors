# %% [markdown]
# ## Final Project Submission
#
# Please fill out:
# * Student name: Lauren Esser
# * Student pace: Full time
# * Scheduled project review date/time: Tuesday, Sept 8 at 4:30 pm
# * Instructor name: James Irving
# * Blog post URL: https://lauren-esser.github.io/osemn_is_awesome

# %% [markdown]
# # Project Approach

# %% [markdown]
# Purpose of this project
#
# Model follows OSEMN framework
#
# Investiage improving R2
#
#
# > In this notebook, I am taking a look at the King County House Sales Dataset with the goal of predicting future sale prices of homes. The main question I have kept in mind during this project is "What can individuals do to increase their home's value?"
#
#
# **Is that long enough**
# **NEED to WRITE MY OWN READ ME
#
# Include:
# - 3 meaningful questions(don't need to present these to non-techincal audience. Just for notebook)
# - 4 meaningful data visualizations with coreesponding interpretations (make sure to label, title, and legened (when appropriate)

# %% [markdown]
# # Tableau Price Visualizations

# %% [markdown]
# ### Price vs. Location

# %% [markdown]
# > Simply by looking at this tableau visualizations, we can see that more of the expensive households are in the northeast region.

# %%
# %%html
# <div class='tableauPlaceholder' id='viz1598550555604' style='position: relative'><noscript><a href='#'><img alt=' ' src='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Pr&#47;Pricevs_Location&#47;Sheet1&#47;1_rss.png' style='border: none' /></a></noscript><object class='tableauViz'  style='display:none;'><param name='host_url' value='https%3A%2F%2Fpublic.tableau.com%2F' /> <param name='embed_code_version' value='3' /> <param name='site_root' value='' /><param name='name' value='Pricevs_Location&#47;Sheet1' /><param name='tabs' value='no' /><param name='toolbar' value='yes' /><param name='static_image' value='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Pr&#47;Pricevs_Location&#47;Sheet1&#47;1.png' /> <param name='animate_transition' value='yes' /><param name='display_static_image' value='yes' /><param name='display_spinner' value='yes' /><param name='display_overlay' value='yes' /><param name='display_count' value='yes' /><param name='language' value='en' /><param name='filter' value='publish=yes' /></object></div>                <script type='text/javascript'>                    var divElement = document.getElementById('viz1598550555604');                    var vizElement = divElement.getElementsByTagName('object')[0];                    vizElement.style.width='100%';vizElement.style.height=(divElement.offsetWidth*0.75)+'px';                    var scriptElement = document.createElement('script');                    scriptElement.src = 'https://public.tableau.com/javascripts/api/viz_v1.js';                    vizElement.parentNode.insertBefore(scriptElement, vizElement);                </script>
# Out:
# <div class='tableauPlaceholder' id='viz1598550555604' style='position: relative'><noscript><a href='#'><img alt=' ' src='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Pr&#47;Pricevs_Location&#47;Sheet1&#47;1_rss.png' style='border: none' /></a></noscript><object class='tableauViz'  style='display:none;'><param name='host_url' value='https%3A%2F%2Fpublic.tableau.com%2F' /> <param name='embed_code_version' value='3' /> <param name='site_root' value='' /><param name='name' value='Pricevs_Location&#47;Sheet1' /><param name='tabs' value='no' /><param name='toolbar' value='yes' /><param name='static_image' value='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Pr&#47;Pricevs_Location&#47;Sheet1&#47;1.png' /> <param name='animate_transition' value='yes' /><param name='display_static_image' value='yes' /><param name='display_spinner' value='yes' /><param name='display_overlay' value='yes' /><param name='display_count' value='yes' /><param name='language' value='en' /><param name='filter' value='publish=yes' /></object></div>                <script type='text/javascript'>                    var divElement = document.getElementById('viz1598550555604');                    var vizElement = divElement.getElementsByTagName('object')[0];                    vizElement.style.width='100%';vizElement.style.height=(divElement.offsetWidth*0.75)+'px';                    var scriptElement = document.createElement('script');                    scriptElement.src = 'https://public.tableau.com/javascripts/api/viz_v1.js';                    vizElement.parentNode.insertBefore(scriptElement, vizElement);                </script>

# %% [markdown]
# ### Price vs. Zipcode

# %% [markdown]
# > Looking at price vs. zipcode we are able to see that it matches with the above tableau. The more expensive houses are in the north/northeast area of King County.

# %%
# %%html
# <div class='tableauPlaceholder' id='viz1598550849044' style='position: relative'><noscript><a href='#'><img alt=' ' src='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Pr&#47;Pricevs_Location&#47;Sheet2&#47;1_rss.png' style='border: none' /></a></noscript><object class='tableauViz'  style='display:none;'><param name='host_url' value='https%3A%2F%2Fpublic.tableau.com%2F' /> <param name='embed_code_version' value='3' /> <param name='path' value='views&#47;Pricevs_Location&#47;Sheet2?:language=en&amp;:embed=y&amp;:display_count=y&amp;publish=yes' /> <param name='toolbar' value='yes' /><param name='static_image' value='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Pr&#47;Pricevs_Location&#47;Sheet2&#47;1.png' /> <param name='animate_transition' value='yes' /><param name='display_static_image' value='yes' /><param name='display_spinner' value='yes' /><param name='display_overlay' value='yes' /><param name='display_count' value='yes' /><param name='language' value='en' /><param name='filter' value='publish=yes' /></object></div>                <script type='text/javascript'>                    var divElement = document.getElementById('viz1598550849044');                    var vizElement = divElement.getElementsByTagName('object')[0];                    vizElement.style.width='100%';vizElement.style.height=(divElement.offsetWidth*0.75)+'px';                    var scriptElement = document.createElement('script');                    scriptElement.src = 'https://public.tableau.com/javascripts/api/viz_v1.js';                    vizElement.parentNode.insertBefore(scriptElement, vizElement);                </script>
# Out:
# <div class='tableauPlaceholder' id='viz1598550849044' style='position: relative'><noscript><a href='#'><img alt=' ' src='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Pr&#47;Pricevs_Location&#47;Sheet2&#47;1_rss.png' style='border: none' /></a></noscript><object class='tableauViz'  style='display:none;'><param name='host_url' value='https%3A%2F%2Fpublic.tableau.com%2F' /> <param name='embed_code_version' value='3' /> <param name='path' value='views&#47;Pricevs_Location&#47;Sheet2?:language=en&amp;:embed=y&amp;:display_count=y&amp;publish=yes' /> <param name='toolbar' value='yes' /><param name='static_image' value='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Pr&#47;Pricevs_Location&#47;Sheet2&#47;1.png' /> <param name='animate_transition' value='yes' /><param name='display_static_image' value='yes' /><param name='display_spinner' value='yes' /><param name='display_overlay' value='yes' /><param name='display_count' value='yes' /><param name='language' value='en' /><param name='filter' value='publish=yes' /></object></div>                <script type='text/javascript'>                    var divElement = document.getElementById('viz1598550849044');                    var vizElement = divElement.getElementsByTagName('object')[0];                    vizElement.style.width='100%';vizElement.style.height=(divElement.offsetWidth*0.75)+'px';                    var scriptElement = document.createElement('script');                    scriptElement.src = 'https://public.tableau.com/javascripts/api/viz_v1.js';                    vizElement.parentNode.insertBefore(scriptElement, vizElement);                </script>

# %% [markdown]
# # Location vs. Yearbuilt

# %% [markdown]
# > I wanted to take a look at where the newer houses were being built in King County. Looking at the tableau below we can see that most new houses are going up northeast of the city as well. This leads me to believe that the new homes are selling for more.

# %%
# %%html
# <div class='tableauPlaceholder' id='viz1598550894188' style='position: relative'><noscript><a href='#'><img alt=' ' src='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Yr&#47;YrBuiltvs_Location&#47;Sheet3&#47;1_rss.png' style='border: none' /></a></noscript><object class='tableauViz'  style='display:none;'><param name='host_url' value='https%3A%2F%2Fpublic.tableau.com%2F' /> <param name='embed_code_version' value='3' /> <param name='site_root' value='' /><param name='name' value='YrBuiltvs_Location&#47;Sheet3' /><param name='tabs' value='no' /><param name='toolbar' value='yes' /><param name='static_image' value='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Yr&#47;YrBuiltvs_Location&#47;Sheet3&#47;1.png' /> <param name='animate_transition' value='yes' /><param name='display_static_image' value='yes' /><param name='display_spinner' value='yes' /><param name='display_overlay' value='yes' /><param name='display_count' value='yes' /><param name='language' value='en' /><param name='filter' value='publish=yes' /></object></div>                <script type='text/javascript'>                    var divElement = document.getElementById('viz1598550894188');                    var vizElement = divElement.getElementsByTagName('object')[0];                    vizElement.style.width='100%';vizElement.style.height=(divElement.offsetWidth*0.75)+'px';                    var scriptElement = document.createElement('script');                    scriptElement.src = 'https://public.tableau.com/javascripts/api/viz_v1.js';                    vizElement.parentNode.insertBefore(scriptElement, vizElement);                </script>
# Out:
# <div class='tableauPlaceholder' id='viz1598550894188' style='position: relative'><noscript><a href='#'><img alt=' ' src='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Yr&#47;YrBuiltvs_Location&#47;Sheet3&#47;1_rss.png' style='border: none' /></a></noscript><object class='tableauViz'  style='display:none;'><param name='host_url' value='https%3A%2F%2Fpublic.tableau.com%2F' /> <param name='embed_code_version' value='3' /> <param name='site_root' value='' /><param name='name' value='YrBuiltvs_Location&#47;Sheet3' /><param name='tabs' value='no' /><param name='toolbar' value='yes' /><param name='static_image' value='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Yr&#47;YrBuiltvs_Location&#47;Sheet3&#47;1.png' /> <param name='animate_transition' value='yes' /><param name='display_static_image' value='yes' /><param name='display_spinner' value='yes' /><param name='display_overlay' value='yes' /><param name='display_count' value='yes' /><param name='language' value='en' /><param name='filter' value='publish=yes' /></object></div>                <script type='text/javascript'>                    var divElement = document.getElementById('viz1598550894188');                    var vizElement = divElement.getElementsByTagName('object')[0];                    vizElement.style.width='100%';vizElement.style.height=(divElement.offsetWidth*0.75)+'px';                    var scriptElement = document.createElement('script');                    scriptElement.src = 'https://public.tableau.com/javascripts/api/viz_v1.js';                    vizElement.parentNode.insertBefore(scriptElement, vizElement);                </script>

# %% [markdown]
# # Obtain Data

# %% [markdown]
# ### Import Data

# %%
#Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

import statsmodels.api as sm
import statsmodels.formula.api as smf
# Out:
# /Users/laurenesser/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
#Import data using pandas
df = pd.read_csv("kc_house_data.csv")
#Set display to maximum rows
pd.set_option('display.max_columns', 0)
df.head()
# Out:
#            id        date     price  ...     long  sqft_living15  sqft_lot15
# 0  7129300520  10/13/2014  221900.0  ... -122.257           1340        5650
# 1  6414100192   12/9/2014  538000.0  ... -122.319           1690        7639
# 2  5631500400   2/25/2015  180000.0  ... -122.233           2720        8062
# 3  2487200875   12/9/2014  604000.0  ... -122.393           1360        5000
# 4  1954400510   2/18/2015  510000.0  ... -122.045           1800        7503
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Check for Duplicates

# %% [markdown]
# > Below I checked for duplicates in the dataframe using the id column:
#
# > **177 duplicates**
#
# > Reasoning for this could be if a specific house sold more than one time over the data collection period. I chose to drop the duplicates for the id column in order to represent each house only once. By using keep = first I chose to keep the first occurring id only and drop any after that.

# %%
#Check for duplicates
duplicates = df[df.duplicated(subset = 'id')]
print(len(duplicates))
duplicates.head()
# Out:
# 177
#              id        date      price  ...     long  sqft_living15  sqft_lot15
# 94   6021501535  12/23/2014   700000.0  ... -122.386           1570        4500
# 314  4139480200   12/9/2014  1400000.0  ... -122.102           3860       11244
# 325  7520000520   3/11/2015   240500.0  ... -122.352           1820        7460
# 346  3969300030  12/29/2014   239900.0  ... -122.240           1020        7138
# 372  2231500030   3/24/2015   530000.0  ... -122.341           1810        6929
#
# [5 rows x 21 columns]

# %%
#Drop duplicates using id column.
df.drop_duplicates(subset ="id", 
                     keep = 'first', inplace = True)

# %%
#Recheck for duplicates
duplicates = df[df.duplicated(subset = 'id')]
print(len(duplicates))
duplicates.head()
# Out:
# 0
# Empty DataFrame
# Columns: [id, date, price, bedrooms, bathrooms, sqft_living, sqft_lot, floors, waterfront, view, condition, grade, sqft_above, sqft_basement, yr_built, yr_renovated, zipcode, lat, long, sqft_living15, sqft_lot15]
# Index: []

# %% [markdown]
# ### Inspect Columns in the DataFrame

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21420 entries, 0 to 21596
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           21420 non-null  object
#  1   price          21420 non-null  float64
#  2   bedrooms       21420 non-null  int64
#  3   bathrooms      21420 non-null  float64
#  4   sqft_living    21420 non-null  int64
#  5   sqft_lot       21420 non-null  int64
#  6   floors         21420 non-null  float64
#  7   waterfront     19067 non-null  float64
#  8   view           21357 non-null  float64
#  9   condition      21420 non-null  int64
#  10  grade          21420 non-null  int64
#  11  sqft_above     21420 non-null  int64
#  12  sqft_basement  21420 non-null  object
#  13  yr_built       21420 non-null  int64
#  14  yr_renovated   17616 non-null  float64
#  15  zipcode        21420 non-null  int64
#  16  lat            21420 non-null  float64
#  17  long           21420 non-null  float64
#  18  sqft_living15  21420 non-null  int64
#  19  sqft_lot15     21420 non-null  int64
# dtypes: float64(8), int64(10), object(2)
# memory usage: 3.4+ MB

# %%
#check len/val
df.id.sort_values()
# Out:
# 2494        1000102
# 6729        1200019
# 8404        1200021
# 8800        2800031
# 3553        3600057
#             ...
# 16723    9842300095
# 3257     9842300485
# 7614     9842300540
# 20963    9895000040
# 15937    9900000190
# Name: id, Length: 21420, dtype: int64

# %%
#drop id since it is no longer needed
df.drop(['id'], axis=1, inplace=True)

# %% [markdown]
# ### Observations

# %% [markdown]
# > - **D-Types**:
#     - float64 = 8
#     - int64 = 10
#     - object = 2 (Need to switch sqft_basement over to float)
# - **Missing Data**:
#     - waterfront
#     - view
#     - yr_renovated

# %% [markdown]
# # Scrub

# %% [markdown]
# ### Check for labeled categorical columns

# %%
#Create categorical variable
cat_cols = df.select_dtypes('object')
cat_cols
# Out:
#              date sqft_basement
# 0      10/13/2014           0.0
# 1       12/9/2014         400.0
# 2       2/25/2015           0.0
# 3       12/9/2014         910.0
# 4       2/18/2015           0.0
# ...           ...           ...
# 21592   5/21/2014           0.0
# 21593   2/23/2015           0.0
# 21594   6/23/2014           0.0
# 21595   1/16/2015           0.0
# 21596  10/15/2014           0.0
#
# [21420 rows x 2 columns]

# %%
#while at it create numerical columns list
num_cols = list(df.select_dtypes('number').columns)
num_cols
# Out:
# ['price',
#  'bedrooms',
#  'bathrooms',
#  'sqft_living',
#  'sqft_lot',
#  'floors',
#  'waterfront',
#  'view',
#  'condition',
#  'grade',
#  'sqft_above',
#  'yr_built',
#  'yr_renovated',
#  'zipcode',
#  'lat',
#  'long',
#  'sqft_living15',
#  'sqft_lot15']

# %% [markdown]
# > Above shows that there are only two columns labeled as an object or categorical column: **date and sqft_basement**. Since sqft_basement is *numerical* I am going to convert it to a float below.

# %%
#Save and convert to float
df.sqft_basement = df.sqft_basement.astype('float')

# %% [markdown]
# >Inspecting unique values of sqft_basement

# %%
#Look at val_counts for sqft_basement
df.sqft_basement.value_counts(dropna = False, normalize=True)
# Out:
# 0.0       0.593697
# ?         0.021102
# 600.0     0.010084
# 500.0     0.009617
# 700.0     0.009570
#             ...
# 2180.0    0.000047
# 2580.0    0.000047
# 20.0      0.000047
# 266.0     0.000047
# 518.0     0.000047
# Name: sqft_basement, Length: 304, dtype: float64

# %%
#replace ? with 0.0
df.sqft_basement = df.sqft_basement.replace('?', '0.0')

# %% [markdown]
# > Here I am assuming that a
# **?** means there is no basement present therefore I switched all question marks over to *0.0* in the data.

# %%
#Recheck val_counts
df.sqft_basement.value_counts(dropna = False, normalize=True)
# Out:
# 0.0       0.614799
# 600.0     0.010084
# 500.0     0.009617
# 700.0     0.009570
# 800.0     0.009384
#             ...
# 875.0     0.000047
# 274.0     0.000047
# 1248.0    0.000047
# 2610.0    0.000047
# 243.0     0.000047
# Name: sqft_basement, Length: 303, dtype: float64

# %% [markdown]
# ### Checking Null Values

# %% [markdown]
# > Installed missingno for first time use. This allows for visualization of the null values before getting started. I can already see that waterfront and yr_renovated will have a high number of nulls.

# %%
import missingno as ms
ms.matrix(df)
# Out:
# <AxesSubplot:>

# %% [markdown]
# > Below I looked to see if there are any rows with over two nulls. Since more information is missing I chose to drop those rows.

# %%
#num. of rows missing amnt of data
df.isna().sum(axis=1).value_counts()
# Out:
# 0    15644
# 1     5334
# 2      440
# 3        2
# dtype: int64

# %%
#Keep rows w/ less than 3 Null
keep_rows = df.isna().sum(axis=1) < 3

# %%
df = df[keep_rows]

# %%
df.isna().sum()
# Out:
# date                0
# price               0
# bedrooms            0
# bathrooms           0
# sqft_living         0
# sqft_lot            0
# floors              0
# waterfront       2351
# view               61
# condition           0
# grade               0
# sqft_above          0
# sqft_basement       0
# yr_built            0
# yr_renovated     3802
# zipcode             0
# lat                 0
# long                0
# sqft_living15       0
# sqft_lot15          0
# dtype: int64

# %% [markdown]
# > **Observations**:
# - Three columns with Null values: *waterfront, view, and yr_renovated*. I will go through each of the columns below.

# %% [markdown]
# ### Waterfront

# %%
#Check majority
df.waterfront.value_counts()
# Out:
# 0.0    18921
# 1.0      146
# Name: waterfront, dtype: int64

# %%
#Fill NaN with 0.0, assume no waterfront
df['waterfront'] = df['waterfront'].fillna(0.0)

# %%
#NaN check
df.isna().sum()
# Out:
# date                0
# price               0
# bedrooms            0
# bathrooms           0
# sqft_living         0
# sqft_lot            0
# floors              0
# waterfront          0
# view               61
# condition           0
# grade               0
# sqft_above          0
# sqft_basement       0
# yr_built            0
# yr_renovated     3802
# zipcode             0
# lat                 0
# long                0
# sqft_living15       0
# sqft_lot15          0
# dtype: int64

# %% [markdown]
# ### View

# %%
#less than 5% consider dropping
df.view.value_counts(dropna = False, normalize = True)
# Out:
# 0.0    0.898917
# 2.0    0.044635
# 3.0    0.023578
# 1.0    0.015361
# 4.0    0.014661
# NaN    0.002848
# Name: view, dtype: float64

# %%
# .2% deciding to drop NaN views
df.dropna(subset = ['view'], inplace=True)

# %%
df.view.isna().sum()
# Out:
# 0

# %% [markdown]
# ### Yr_renovated

# %%
#Assume NaN = no reno & replace with 0
df['yr_renovated'] = df['yr_renovated'].fillna(0.0)

# %%
#Check NaN
df.yr_renovated.isna().sum()
# Out:
# 0

# %% [markdown]
# ### Check for abnormal symbols or characters

# %%
#Check for abnormal symbols etc.
for col in df.columns:
    try: 
        print(col, '\n', df[col].value_counts(normalize=True).head(), '\n\n')
    except:
        (print(col, df[col].value_counts()))
# Out:
# date
#  6/23/2014    0.006649
# 6/25/2014    0.006134
# 6/26/2014    0.006134
# 7/8/2014     0.005947
# 4/27/2015    0.005806
# Name: date, dtype: float64
#
#
# price
#  350000.0    0.008007
# 450000.0    0.007960
# 550000.0    0.007304
# 500000.0    0.007070
# 425000.0    0.007023
# Name: price, dtype: float64
#
#
# bedrooms
#  3    0.454090
# 4    0.319895
# 2    0.127827
# 5    0.074027
# 6    0.012314
# Name: bedrooms, dtype: float64
#
#
# bathrooms
#  2.50    0.249988
# 1.00    0.177178
# 1.75    0.140797
# 2.25    0.094629
# 2.00    0.089385
# Name: bathrooms, dtype: float64
#
#
# sqft_living
#  1300    0.006368
# 1440    0.006227
# 1400    0.006134
# 1800    0.005993
# 1660    0.005993
# Name: sqft_living, dtype: float64
#
#
# sqft_lot
#  5000    0.016575
# 6000    0.013391
# 4000    0.011659
# 7200    0.010207
# 7500    0.005478
# Name: sqft_lot, dtype: float64
#
#
# floors
#  1.0    0.492672
# 2.0    0.382966
# 1.5    0.088074
# 3.0    0.028515
# 2.5    0.007445
# Name: floors, dtype: float64
#
#
# waterfront
#  0.0    0.993211
# 1.0    0.006789
# Name: waterfront, dtype: float64
#
#
# view
#  0.0    0.901484
# 2.0    0.044763
# 3.0    0.023646
# 1.0    0.015405
# 4.0    0.014702
# Name: view, dtype: float64
#
#
# condition
#  3    0.649014
# 4    0.263286
# 5    0.078803
# 2    0.007585
# 1    0.001311
# Name: condition, dtype: float64
#
#
# grade
#  7     0.414993
# 8     0.282296
# 9     0.121506
# 6     0.093084
# 10    0.052723
# Name: grade, dtype: float64
#
#
# sqft_above
#  1300    0.009833
# 1010    0.009505
# 1200    0.009411
# 1220    0.008662
# 1140    0.008522
# Name: sqft_above, dtype: float64
#
#
# sqft_basement
#  0.0      0.615208
# 600.0    0.010067
# 500.0    0.009646
# 700.0    0.009552
# 800.0    0.009411
# Name: sqft_basement, dtype: float64
#
#
# yr_built
#  2014    0.026127
# 2006    0.021211
# 2005    0.020977
# 2004    0.019947
# 2003    0.019619
# Name: yr_built, dtype: float64
#
#
# yr_renovated
#  0.0       0.965398
# 2014.0    0.003418
# 2003.0    0.001452
# 2013.0    0.001452
# 2007.0    0.001405
# Name: yr_renovated, dtype: float64
#
#
# zipcode
#  98103    0.028047
# 98038    0.027298
# 98115    0.026830
# 98052    0.026689
# 98117    0.025659
# Name: zipcode, dtype: float64
#
#
# lat
#  47.5322    0.000796
# 47.5491    0.000796
# 47.6624    0.000796
# 47.6846    0.000796
# 47.6955    0.000749
# Name: lat, dtype: float64
#
#
# long
#  -122.290    0.005291
# -122.300    0.005057
# -122.362    0.004776
# -122.291    0.004682
# -122.363    0.004635
# Name: long, dtype: float64
#
#
# sqft_living15
#  1540    0.009037
# 1440    0.008896
# 1560    0.008850
# 1500    0.008288
# 1460    0.007866
# Name: sqft_living15, dtype: float64
#
#
# sqft_lot15
#  5000    0.019853
# 4000    0.016575
# 6000    0.013345
# 7200    0.009786
# 4800    0.006743
# Name: sqft_lot15, dtype: float64

# %% [markdown]
# > In the scrub section I took care of null values, converted an object column to float, and checked for abnormal characters or symbols.

# %% [markdown]
# # Explore

# %% [markdown]
# > Below I set the color palette for all of my visualizations.

# %%
sns.palplot(sns.color_palette("BuGn_r"))

# %%
sns.set_palette("BuGn_r")

# %% [markdown]
# > Here I examining the target column of price.

# %%
#examine target
target = 'price'
sns.distplot(df[target])
# Out:
# <AxesSubplot:xlabel='price'>

# %% [markdown]
# > Displot looks like a slight left skew.

# %%
sns.boxplot(y= df[target])
# Out:
# <AxesSubplot:ylabel='price'>

# %% [markdown]
# > Boxplot shows outliers on the high price end.

# %%
sns.jointplot(data=df, x = 'bedrooms', y=target,  kind = 'reg')

# %% [markdown]
# > Set up a joint plot to compare dependent and independent variables. Based on this plot I am considering removing bedroom outliers in the future.
#
# > Below is based off of in class lesson to make sorting through graphs of columns easier using interact.

# %%
joint = sns.jointplot(data=df, x = 'bedrooms', y=target,  kind = 'reg')
fig = joint.fig
ax = fig.get_axes()

# %%
def joint_graphs(df, col, target = 'price'):
    
    sns.set(rc={'axes.labelsize': 14})
    sns.set_palette("BuGn_r")        
    joint = sns.jointplot(data = df, x = col, y=target,
                          kind='reg', height = 7)
                          
    plt.suptitle(f" Comparing {col} and {target}", fontsize = 14)
    return joint

# %%
joint_graphs(df, 'bedrooms')

# %%
joint_graphs(df, 'sqft_lot')

# %% [markdown]
# > Will probably look to remove outliers from sqft_lot later in notebook.

# %%
from ipywidgets import interact

# %%
@interact 
def show_plot(col=num_cols):
    joint_graphs(df, col)
# Out:
# interactive(children=(Dropdown(description='col', options=('price', 'bedrooms', 'bathrooms', 'sqft_living', 's…

# %% [markdown]
# ### Ordinal Categorical Data

# %% [markdown]
# > Below I decided to make **zipcode** and **condition** categorical data. Using get_dummies I one-hot encoded those columns.

# %%
#Use Dummy encoding/One-Hot Encoding
df_ohe = pd.get_dummies(df, columns=['zipcode', 'condition'], drop_first=True)

# %%
df_ohe.head()
# Out:
#          date     price  bedrooms  ...  condition_3  condition_4  condition_5
# 0  10/13/2014  221900.0         3  ...            1            0            0
# 1   12/9/2014  538000.0         3  ...            1            0            0
# 2   2/25/2015  180000.0         2  ...            1            0            0
# 3   12/9/2014  604000.0         4  ...            0            0            1
# 4   2/18/2015  510000.0         3  ...            1            0            0
#
# [5 rows x 91 columns]

# %% [markdown]
# ### First R-squared Model

# %% [markdown]
# > Drop price since it is the target column and date since it is not being used.

# %%
features = '+'.join(df_ohe.drop(columns=['price', 'date']).columns)
features
# Out:
# 'bedrooms+bathrooms+sqft_living+sqft_lot+floors+waterfront+view+grade+sqft_above+sqft_basement+yr_built+yr_renovated+lat+long+sqft_living15+sqft_lot15+zipcode_98002+zipcode_98003+zipcode_98004+zipcode_98005+zipcode_98006+zipcode_98007+zipcode_98008+zipcode_98010+zipcode_98011+zipcode_98014+zipcode_98019+zipcode_98022+zipcode_98023+zipcode_98024+zipcode_98027+zipcode_98028+zipcode_98029+zipcode_98030+zipcode_98031+zipcode_98032+zipcode_98033+zipcode_98034+zipcode_98038+zipcode_98039+zipcode_98040+zipcode_98042+zipcode_98045+zipcode_98052+zipcode_98053+zipcode_98055+zipcode_98056+zipcode_98058+zipcode_98059+zipcode_98065+zipcode_98070+zipcode_98072+zipcode_98074+zipcode_98075+zipcode_98077+zipcode_98092+zipcode_98102+zipcode_98103+zipcode_98105+zipcode_98106+zipcode_98107+zipcode_98108+zipcode_98109+zipcode_98112+zipcode_98115+zipcode_98116+zipcode_98117+zipcode_98118+zipcode_98119+zipcode_98122+zipcode_98125+zipcode_98126+zipcode_98133+zipcode_98136+zipcode_98144+zipcode_98146+zipcode_98148+zipcode_98155+zipcode_98166+zipcode_98168+zipcode_98177+zipcode_98178+zipcode_98188+zipcode_98198+zipcode_98199+condition_2+condition_3+condition_4+condition_5'

# %%
formula = target + '~' + features
model = smf.ols(formula, df_ohe).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0
# zipcode_98116  2.216e+05   2.15e+04     10.326      0.000     1.8e+05    2.64e+05
# zipcode_98117  2.294e+05   2.67e+04      8.592      0.000    1.77e+05    2.82e+05
# zipcode_98118  1.246e+05   1.88e+04      6.642      0.000    8.78e+04    1.61e+05
# zipcode_98119  4.003e+05    2.6e+04     15.398      0.000    3.49e+05    4.51e+05
# zipcode_98122  2.758e+05   2.32e+04     11.882      0.000     2.3e+05    3.21e+05
# zipcode_98125  1.168e+05   2.85e+04      4.097      0.000    6.09e+04    1.73e+05
# zipcode_98126  1.339e+05   1.97e+04      6.791      0.000    9.52e+04    1.73e+05
# zipcode_98133  7.408e+04   2.94e+04      2.519      0.012    1.64e+04    1.32e+05
# zipcode_98136  1.864e+05   2.02e+04      9.224      0.000    1.47e+05    2.26e+05
# zipcode_98144  2.204e+05   2.16e+04     10.206      0.000    1.78e+05    2.63e+05
# zipcode_98146   6.28e+04   1.81e+04      3.472      0.001    2.73e+04    9.83e+04
# zipcode_98148  2.994e+04   2.46e+04      1.218      0.223   -1.82e+04    7.81e+04
# zipcode_98155  5.574e+04   3.06e+04      1.823      0.068   -4202.757    1.16e+05
# zipcode_98166  1.352e+04   1.65e+04      0.817      0.414   -1.89e+04    4.59e+04
# zipcode_98168  3.808e+04   1.75e+04      2.179      0.029    3831.709    7.23e+04
# zipcode_98177  1.177e+05   3.07e+04      3.837      0.000    5.76e+04    1.78e+05
# zipcode_98178  2307.7909    1.8e+04      0.128      0.898   -3.31e+04    3.77e+04
# zipcode_98188  8596.2667   1.85e+04      0.465      0.642   -2.76e+04    4.48e+04
# zipcode_98198 -2.299e+04   1.41e+04     -1.634      0.102   -5.06e+04    4588.365
# zipcode_98199  3.015e+05   2.53e+04     11.895      0.000    2.52e+05    3.51e+05
# condition_2    7.023e+04    3.3e+04      2.131      0.033    5620.235    1.35e+05
# condition_3    6.217e+04   3.06e+04      2.034      0.042    2257.044    1.22e+05
# condition_4    8.186e+04   3.06e+04      2.678      0.007    2.19e+04    1.42e+05
# condition_5    1.251e+05   3.08e+04      4.069      0.000    6.49e+04    1.85e+05
# ==============================================================================
# Omnibus:                    20581.895   Durbin-Watson:                   1.995
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          4232455.085
# Skew:                           4.161   Prob(JB):                         0.00
# Kurtosis:                      71.462   Cond. No.                     2.84e+08
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.84e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
sm.graphics.qqplot(model.resid, fit=True, 
                       line= '45', color = 'g')

# %%
ax = sns.scatterplot(df_ohe[target], model.resid, color = 'g')
ax.axhline(linewidth=2, color='r')

# %% [markdown]
# > Create function to make it quicker to graph visualizations for model.

# %%
def create_visuals(y_true):
    fig, axes = plt.subplots(ncols=2, figsize=(10,6))
    
    sm.graphics.qqplot(model.resid, fit=True, 
                       line= '45', color = 'g', ax=axes[0])
   
    ax = axes[1]
    ax = sns.scatterplot(y_true, model.resid, color = 'g')
    ax.axhline(linewidth=2, color='r')
    plt.suptitle(f" QQplot and Homoskedasticity Check", fontsize = 14)
    plt.tight_layout()

# %%
create_visuals(df_ohe[target])

# %% [markdown]
# >**Observations**:
# - Higher R-squared of .809. First R-squared was .700. Went back and decided to scrub data better.
# - Problem P-value rows
# - Multicolinearity of 2.84e+08

# %% [markdown]
# ### Dealing with P-Values

# %%
p_val = round(model.pvalues.sort_values(ascending=True), 3)

# %%
p_val
# Out:
# waterfront       0.000
# zipcode_98039    0.000
# view             0.000
# grade            0.000
# zipcode_98004    0.000
#                  ...
# zipcode_98031    0.612
# zipcode_98032    0.614
# zipcode_98188    0.642
# zipcode_98030    0.798
# zipcode_98178    0.898
# Length: 90, dtype: float64

# %%
p_removal = list(p_val[p_val > .05].index)

# %%
p_removal
# Out:
# ['sqft_basement',
#  'zipcode_98003',
#  'zipcode_98155',
#  'zipcode_98077',
#  'zipcode_98092',
#  'zipcode_98198',
#  'zipcode_98055',
#  'zipcode_98019',
#  'zipcode_98011',
#  'zipcode_98148',
#  'zipcode_98028',
#  'zipcode_98042',
#  'zipcode_98058',
#  'zipcode_98166',
#  'zipcode_98031',
#  'zipcode_98032',
#  'zipcode_98188',
#  'zipcode_98030',
#  'zipcode_98178']

# %% [markdown]
# > Above I am checking to see if 'Intercept' is listed in the p_removal list. It is not so I can proceed.

# %%
# % of overall data to drop
len(p_removal)/len(df_ohe.columns)
# Out:
# 0.2087912087912088

# %%
for col in p_removal:
    if col in df_ohe.columns:
        df_ohe.drop(columns=col, inplace = True)

# %%
features = '+'.join(df_ohe.drop(columns=['price', 'date']).columns)

# %%
formula = target + '~' + features
model = smf.ols(formula, df_ohe).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.809
# Model:                            OLS   Adj. R-squared:                  0.808
# Method:                 Least Squares   F-statistic:                     1286.
# Date:                Tue, 01 Sep 2020   Prob (F-statistic):               0.00
# Time:                        09:46:56   Log-Likelihood:            -2.8627e+05
# No. Observations:               21357   AIC:                         5.727e+05
# Df Residuals:                   21286   BIC:                         5.732e+05
# Df Model:                          70
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept     -2.601e+07   2.89e+06     -8.992      0.000   -3.17e+07   -2.03e+07
# bedrooms      -2.712e+04   1547.075    -17.530      0.000   -3.02e+04   -2.41e+04
# bathrooms      2.314e+04   2645.260      8.748      0.000     1.8e+04    2.83e+04
# sqft_living     128.1656      3.563     35.976      0.000     121.183     135.148
# sqft_lot          0.2401      0.038      6.243      0.000       0.165       0.316
# floors        -4.461e+04   3166.795    -14.088      0.000   -5.08e+04   -3.84e+04
# waterfront     6.649e+05   1.48e+04     45.072      0.000    6.36e+05    6.94e+05
# view           5.797e+04   1738.985     33.334      0.000    5.46e+04    6.14e+04
# grade          5.824e+04   1828.118     31.857      0.000    5.47e+04    6.18e+04
# sqft_above       79.9257      3.643     21.942      0.000      72.786      87.065
# yr_built       -707.7043     64.715    -10.936      0.000    -834.551    -580.857
# yr_renovated     20.2542      3.216      6.298      0.000      13.951      26.558
# lat            3.197e+05   1.34e+04     23.856      0.000    2.93e+05    3.46e+05
# long          -9.621e+04   2.24e+04     -4.290      0.000    -1.4e+05   -5.23e+04
# sqft_living15     9.5898      2.884      3.325      0.001       3.936      15.243
# sqft_lot15       -0.1414      0.060     -2.346      0.019      -0.260      -0.023
# zipcode_98112  5.249e+05   1.09e+04     48.119      0.000    5.04e+05    5.46e+05
# zipcode_98115   2.17e+05   8041.306     26.990      0.000    2.01e+05    2.33e+05
# zipcode_98116  2.035e+05   1.02e+04     19.867      0.000    1.83e+05    2.24e+05
# zipcode_98117  1.968e+05   8780.147     22.410      0.000     1.8e+05    2.14e+05
# zipcode_98118  1.053e+05   7872.677     13.381      0.000    8.99e+04    1.21e+05
# zipcode_98119  3.726e+05    1.3e+04     28.591      0.000    3.47e+05    3.98e+05
# zipcode_98122  2.493e+05   1.04e+04     23.911      0.000    2.29e+05     2.7e+05
# zipcode_98125   7.72e+04   9209.630      8.382      0.000    5.91e+04    9.52e+04
# zipcode_98126  1.186e+05   9708.322     12.214      0.000    9.96e+04    1.38e+05
# zipcode_98133  3.409e+04   8983.658      3.795      0.000    1.65e+04    5.17e+04
# zipcode_98136  1.724e+05    1.1e+04     15.609      0.000    1.51e+05    1.94e+05
# zipcode_98144  1.967e+05   9534.753     20.634      0.000    1.78e+05    2.15e+05
# zipcode_98146  5.217e+04   1.04e+04      5.014      0.000    3.18e+04    7.26e+04
# zipcode_98168  2.673e+04   1.04e+04      2.559      0.010    6261.013    4.72e+04
# zipcode_98177  7.811e+04   1.16e+04      6.745      0.000    5.54e+04    1.01e+05
# zipcode_98199  2.748e+05   1.06e+04     25.903      0.000    2.54e+05    2.96e+05
# condition_2    7.053e+04    3.3e+04      2.140      0.032    5928.838    1.35e+05
# condition_3    6.165e+04   3.06e+04      2.017      0.044    1742.711    1.22e+05
# condition_4    8.165e+04   3.06e+04      2.671      0.008    2.17e+04    1.42e+05
# condition_5    1.254e+05   3.07e+04      4.077      0.000    6.51e+04    1.86e+05
# ==============================================================================
# Omnibus:                    20569.706   Durbin-Watson:                   1.994
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          4222633.505
# Skew:                           4.157   Prob(JB):                         0.00
# Kurtosis:                      71.382   Cond. No.                     1.33e+08
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.33e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# >**Observations**:
# - R-squared did not change .809
# - P-values taken care of
# - Multicolinearity dropped to 1.33e+.08

# %% [markdown]
# ### SCRUB: Check for multicollinearity

# %%
df_ohe.shape
# Out:
# (21357, 72)

# %%
df_ohe.iloc[:, 2:72]
# Out:
#        bedrooms  bathrooms  sqft_living  ...  condition_3  condition_4  condition_5
# 0             3       1.00         1180  ...            1            0            0
# 1             3       2.25         2570  ...            1            0            0
# 2             2       1.00          770  ...            1            0            0
# 3             4       3.00         1960  ...            0            0            1
# 4             3       2.00         1680  ...            1            0            0
# ...         ...        ...          ...  ...          ...          ...          ...
# 21592         3       2.50         1530  ...            1            0            0
# 21593         4       2.50         2310  ...            1            0            0
# 21594         2       0.75         1020  ...            1            0            0
# 21595         3       2.50         1600  ...            1            0            0
# 21596         2       0.75         1020  ...            1            0            0
#
# [21357 rows x 70 columns]

# %% [markdown]
# > Take a copy of the data without the target variable of "price". Also dropped "date" because keeping it in won't lead to meaningful results.

# %%
data_pred = df_ohe.iloc[:, 2:72]
data_pred.head()
# Out:
#    bedrooms  bathrooms  sqft_living  ...  condition_3  condition_4  condition_5
# 0         3       1.00         1180  ...            1            0            0
# 1         3       2.25         2570  ...            1            0            0
# 2         2       1.00          770  ...            1            0            0
# 3         4       3.00         1960  ...            0            0            1
# 4         3       2.00         1680  ...            1            0            0
#
# [5 rows x 70 columns]

# %% [markdown]
# > Creating a correlation matrix. Negative numbers represent negative linear relationships whereas positive numbers represent a positive linear relationship.

# %%
data_pred.corr()
# Out:
#                bedrooms  bathrooms  ...  condition_4  condition_5
# bedrooms       1.000000   0.515245  ...    -0.009628     0.026836
# bathrooms      0.515245   1.000000  ...    -0.168274    -0.036391
# sqft_living    0.578790   0.755037  ...    -0.084950    -0.019755
# sqft_lot       0.032756   0.088328  ...     0.013178    -0.014100
# floors         0.177177   0.501502  ...    -0.259715    -0.121381
# ...                 ...        ...  ...          ...          ...
# zipcode_98199 -0.021716   0.008331  ...    -0.005234     0.023321
# condition_2   -0.049304  -0.074046  ...    -0.052264    -0.025570
# condition_3    0.005079   0.192481  ...    -0.812918    -0.397721
# condition_4   -0.009628  -0.168274  ...     1.000000    -0.174848
# condition_5    0.026836  -0.036391  ...    -0.174848     1.000000
#
# [70 rows x 70 columns]

# %% [markdown]
# > Take a look to see how many highly correlated variables we have. I set the cut-off as .75. Where it states true leads me to believe there is high correlation.

# %%
abs(data_pred.corr()) > 0.75
# Out:
#                bedrooms  bathrooms  ...  condition_4  condition_5
# bedrooms           True      False  ...        False        False
# bathrooms         False       True  ...        False        False
# sqft_living       False       True  ...        False        False
# sqft_lot          False      False  ...        False        False
# floors            False      False  ...        False        False
# ...                 ...        ...  ...          ...          ...
# zipcode_98199     False      False  ...        False        False
# condition_2       False      False  ...        False        False
# condition_3       False      False  ...         True        False
# condition_4       False      False  ...         True        False
# condition_5       False      False  ...        False         True
#
# [70 rows x 70 columns]

# %% [markdown]
# > Creating a heatmap to show the correlation matrix as a visualization. The lighter the number the higher the correlation.

# %%
corr = data_pred.corr().abs()
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True
with sns.axes_style("white"):
    f, ax = plt.subplots(figsize=(28, 20))
    ax = sns.heatmap(corr, mask=mask, annot = True, linewidths=1, 
                     square=True, cbar_kws={'shrink':0.6}, 
                     cmap="BuGn_r")

# %% [markdown]
# > Below I calculated multicolinarity using the module method and what was shown in class. Based on results and discussing with instructor I chose to go with vif.

# %%
# # save absolute value of correlation matrix as a data frame
# # converts all values to absolute value
# # stacks the row:column pairs into a multindex
# # reset the index to set the multindex to seperate columns
# # sort values. 0 is the column automatically generated by the stacking

# df1 = data_pred.corr().abs().stack().reset_index().sort_values(0, ascending=False)

# #zip new columns into pairs
# df1['pairs'] = list(zip(df1.level_0, df1.level_1))

# #set index to pairs
# df1.set_index(['pairs'], inplace=True)

# #drop level columns
# df1.drop(columns=['level_1', 'level_0'], inplace=True)

# #rename from 0 to cc
# df1.columns = ['cc']
# df1.drop_duplicates(inplace=True)

# %%
#df1[(df1.cc>.75) & (df1.cc< 1)]

# %% [markdown]
# > **Observation from Module Method**:
# - sqft_living has high correlation with sqft_above, grade, sqft_living15, and bathrooms.
# - Condition 3 and 4
# - Grade with sqft_above
#
#
#
# >- Went through and dropped columns and the multicollinearity did not change. Readding to data set.

# %% [markdown]
# ### Testing with VIF

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
df_ohe = df_ohe.drop('date', axis=1)

# %%
X = df_ohe.drop('price', axis=1)
X = sm.add_constant(X)
X.shape
# Out:
# (21357, 71)

# %%
vif = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]

# %%
vif_results = pd.Series(dict(zip(X.columns, vif)))
vif_results
# Out:
# const            6.926693e+06
# bedrooms         1.697360e+00
# bathrooms        3.419968e+00
# sqft_living      8.858012e+00
# sqft_lot         2.109229e+00
#                      ...
# zipcode_98199    1.354231e+00
# condition_2      6.770880e+00
# condition_3      1.761646e+02
# condition_4      1.500519e+02
# condition_5      5.682283e+01
# Length: 71, dtype: float64

# %%
threshold = 6
bad_vif = list(vif_results[vif_results>threshold].index)
if 'const' in bad_vif:
    bad_vif.remove('const') 
bad_vif
# Out:
# ['sqft_living',
#  'sqft_above',
#  'long',
#  'condition_2',
#  'condition_3',
#  'condition_4',
#  'condition_5']

# %%
for col in bad_vif:
    if col in df_ohe.columns:
        df_ohe.drop(columns=col, inplace = True)

# %%
features = '+'.join(df_ohe.drop(columns= 'price').columns)
features
# Out:
# 'bedrooms+bathrooms+sqft_lot+floors+waterfront+view+grade+yr_built+yr_renovated+lat+sqft_living15+sqft_lot15+zipcode_98002+zipcode_98004+zipcode_98005+zipcode_98006+zipcode_98007+zipcode_98008+zipcode_98010+zipcode_98014+zipcode_98022+zipcode_98023+zipcode_98024+zipcode_98027+zipcode_98029+zipcode_98033+zipcode_98034+zipcode_98038+zipcode_98039+zipcode_98040+zipcode_98045+zipcode_98052+zipcode_98053+zipcode_98056+zipcode_98059+zipcode_98065+zipcode_98070+zipcode_98072+zipcode_98074+zipcode_98075+zipcode_98102+zipcode_98103+zipcode_98105+zipcode_98106+zipcode_98107+zipcode_98108+zipcode_98109+zipcode_98112+zipcode_98115+zipcode_98116+zipcode_98117+zipcode_98118+zipcode_98119+zipcode_98122+zipcode_98125+zipcode_98126+zipcode_98133+zipcode_98136+zipcode_98144+zipcode_98146+zipcode_98168+zipcode_98177+zipcode_98199'

# %%
formula = target + '~' + features
model = smf.ols(formula, df_ohe).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.764
# Model:                            OLS   Adj. R-squared:                  0.763
# Method:                 Least Squares   F-statistic:                     1095.
# Date:                Tue, 01 Sep 2020   Prob (F-statistic):               0.00
# Time:                        09:47:32   Log-Likelihood:            -2.8851e+05
# No. Observations:               21357   AIC:                         5.771e+05
# Df Residuals:                   21293   BIC:                         5.777e+05
# Df Model:                          63
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept     -1.123e+07   7.19e+05    -15.624      0.000   -1.26e+07   -9.82e+06
# bedrooms       6772.1106   1615.523      4.192      0.000    3605.564    9938.658
# bathrooms      9.326e+04   2612.658     35.697      0.000    8.81e+04    9.84e+04
# sqft_lot          0.3785      0.043      8.890      0.000       0.295       0.462
# floors        -1.324e+04   3072.369     -4.310      0.000   -1.93e+04   -7218.653
# waterfront      7.01e+05   1.64e+04     42.832      0.000    6.69e+05    7.33e+05
# view           5.945e+04   1896.268     31.352      0.000    5.57e+04    6.32e+04
# grade          1.114e+05   1832.787     60.768      0.000    1.08e+05    1.15e+05
# zipcode_98105  3.103e+05   1.26e+04     24.581      0.000    2.86e+05    3.35e+05
# zipcode_98106  6.977e+04   1.03e+04      6.798      0.000    4.97e+04    8.99e+04
# zipcode_98107  1.817e+05   1.19e+04     15.316      0.000    1.58e+05    2.05e+05
# zipcode_98108  4.251e+04   1.35e+04      3.158      0.002    1.61e+04    6.89e+04
# zipcode_98109   3.35e+05   1.77e+04     18.957      0.000       3e+05     3.7e+05
# zipcode_98112  4.759e+05   1.19e+04     40.159      0.000    4.53e+05    4.99e+05
# zipcode_98115  1.975e+05   8611.373     22.936      0.000    1.81e+05    2.14e+05
# zipcode_98116  1.807e+05   1.05e+04     17.217      0.000     1.6e+05    2.01e+05
# zipcode_98117  1.839e+05   8837.005     20.810      0.000    1.67e+05    2.01e+05
# zipcode_98118  9.217e+04   8590.263     10.730      0.000    7.53e+04    1.09e+05
# zipcode_98119  3.044e+05   1.39e+04     21.878      0.000    2.77e+05    3.32e+05
# zipcode_98122  1.806e+05   1.13e+04     15.977      0.000    1.58e+05    2.03e+05
# zipcode_98125  7.243e+04   9956.161      7.275      0.000    5.29e+04    9.19e+04
# zipcode_98126  1.215e+05   1.01e+04     12.047      0.000    1.02e+05    1.41e+05
# zipcode_98133  3.904e+04   9359.397      4.171      0.000    2.07e+04    5.74e+04
# zipcode_98136  1.515e+05   1.15e+04     13.144      0.000    1.29e+05    1.74e+05
# zipcode_98144  1.679e+05   1.03e+04     16.249      0.000    1.48e+05    1.88e+05
# zipcode_98146  6.992e+04    1.1e+04      6.337      0.000    4.83e+04    9.15e+04
# zipcode_98168  4.516e+04   1.14e+04      3.974      0.000    2.29e+04    6.74e+04
# zipcode_98177  8.804e+04   1.22e+04      7.212      0.000    6.41e+04    1.12e+05
# zipcode_98199  2.511e+05   1.08e+04     23.219      0.000     2.3e+05    2.72e+05
# ==============================================================================
# Omnibus:                    22943.850   Durbin-Watson:                   1.988
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          7035284.916
# Skew:                           4.926   Prob(JB):                         0.00
# Kurtosis:                      91.368   Cond. No.                     2.98e+07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.98e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# > **Observations**:
# - R-squared dropped to .764
# - P-values sqft_lot15 over, zipcode_98014, 98070
# - Multicolinearity dropped to 2.98e+07

# %%
create_visuals(df_ohe[target])

# %%
def p_val_removal(df):
    p_val = round(model.pvalues.sort_values(ascending=True), 3)
    p_removal = list(p_val[p_val > .05].index)
    len(p_removal)/len(df_ohe.columns)
    for col in p_removal:
        if col in df.columns:
            df.drop(columns=col, inplace = True)

# %%
p_val_removal(df_ohe)

# %%
df_ohe.head()
# Out:
#       price  bedrooms  bathrooms  ...  zipcode_98168  zipcode_98177  zipcode_98199
# 0  221900.0         3       1.00  ...              0              0              0
# 1  538000.0         3       2.25  ...              0              0              0
# 2  180000.0         2       1.00  ...              0              0              0
# 3  604000.0         4       3.00  ...              0              0              0
# 4  510000.0         3       2.00  ...              0              0              0
#
# [5 rows x 61 columns]

# %%
features = '+'.join(df_ohe.drop(columns='price').columns)

# %%
formula = target + '~' + features
model = smf.ols(formula, df_ohe).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0
# zipcode_98059  5.737e+04   8703.069      6.592      0.000    4.03e+04    7.44e+04
# zipcode_98065   5.49e+04   1.07e+04      5.132      0.000    3.39e+04    7.59e+04
# zipcode_98072  2.313e+04   1.18e+04      1.960      0.050      -3.295    4.63e+04
# zipcode_98074  7.066e+04   9277.435      7.616      0.000    5.25e+04    8.88e+04
# zipcode_98075  9.187e+04   1.01e+04      9.078      0.000     7.2e+04    1.12e+05
# zipcode_98102  3.472e+05   1.81e+04     19.194      0.000    3.12e+05    3.83e+05
# zipcode_98103  1.878e+05   8612.110     21.808      0.000    1.71e+05    2.05e+05
# zipcode_98105  3.091e+05   1.26e+04     24.528      0.000    2.84e+05    3.34e+05
# zipcode_98106  6.923e+04   1.02e+04      6.756      0.000    4.91e+04    8.93e+04
# zipcode_98107  1.804e+05   1.18e+04     15.243      0.000    1.57e+05    2.04e+05
# zipcode_98108  4.188e+04   1.35e+04      3.114      0.002    1.55e+04    6.82e+04
# zipcode_98109  3.339e+05   1.77e+04     18.911      0.000    2.99e+05    3.69e+05
# zipcode_98112  4.748e+05   1.18e+04     40.137      0.000    4.52e+05    4.98e+05
# zipcode_98115  1.961e+05   8569.537     22.883      0.000    1.79e+05    2.13e+05
# zipcode_98116    1.8e+05   1.05e+04     17.183      0.000    1.59e+05    2.01e+05
# zipcode_98117  1.825e+05   8795.141     20.749      0.000    1.65e+05       2e+05
# zipcode_98118  9.163e+04   8570.039     10.692      0.000    7.48e+04    1.08e+05
# zipcode_98119  3.033e+05   1.39e+04     21.829      0.000    2.76e+05    3.31e+05
# zipcode_98122  1.796e+05   1.13e+04     15.923      0.000    1.57e+05    2.02e+05
# zipcode_98125  7.086e+04   9912.168      7.149      0.000    5.14e+04    9.03e+04
# zipcode_98126   1.21e+05   1.01e+04     12.017      0.000    1.01e+05    1.41e+05
# zipcode_98133  3.729e+04   9307.782      4.006      0.000     1.9e+04    5.55e+04
# zipcode_98136  1.511e+05   1.15e+04     13.125      0.000    1.29e+05    1.74e+05
# zipcode_98144  1.671e+05   1.03e+04     16.205      0.000    1.47e+05    1.87e+05
# zipcode_98146  6.972e+04    1.1e+04      6.327      0.000    4.81e+04    9.13e+04
# zipcode_98168  4.495e+04   1.14e+04      3.960      0.000    2.27e+04    6.72e+04
# zipcode_98177  8.633e+04   1.22e+04      7.094      0.000    6.25e+04     1.1e+05
# zipcode_98199  2.499e+05   1.08e+04     23.167      0.000    2.29e+05    2.71e+05
# ==============================================================================
# Omnibus:                    22946.839   Durbin-Watson:                   1.988
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          7041648.279
# Skew:                           4.927   Prob(JB):                         0.00
# Kurtosis:                      91.408   Cond. No.                     2.56e+07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.56e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# > **Observations**:
# - R-squared still .764
# - P-values  fixed
# - Multicolinearity dropped to 2.56e+07

# %%
create_visuals(df_ohe[target])

# %% [markdown]
# ## Question: Do outliers have an impact on my model?

# %% [markdown]
# ### SCRUB: Check for normality and outliers

# %%
df_ohe.hist(figsize=(12,12));

# %% [markdown]
# ### Using Z-score

# %%
import scipy.stats as stats

# %%
from scipy.stats import zscore
#convert to z-score
df_ohe_z = df_ohe.apply(zscore)

# %%
#check absolute
df_ohe_z.abs()
# Out:
#           price  bedrooms  ...  zipcode_98177  zipcode_98199
# 0      0.869050  0.403881  ...       0.109491       0.122352
# 1      0.006819  0.403881  ...       0.109491       0.122352
# 2      0.983341  1.484386  ...       0.109491       0.122352
# 3      0.173211  0.676625  ...       0.109491       0.122352
# 4      0.083195  0.403881  ...       0.109491       0.122352
# ...         ...       ...  ...            ...            ...
# 21592  0.492352  0.403881  ...       0.109491       0.122352
# 21593  0.383243  0.676625  ...       0.109491       0.122352
# 21594  0.377512  1.484386  ...       0.109491       0.122352
# 21595  0.383243  0.403881  ...       0.109491       0.122352
# 21596  0.587822  1.484386  ...       0.109491       0.122352
#
# [21357 rows x 61 columns]

# %%
#make a list of outliers
zFP = np.abs(stats.zscore(df_ohe))
print(zFP)
# Out:
# [[0.86904954 0.40388059 1.45554871 ... 0.1116602  0.10949086 0.1223522 ]
#  [0.00681853 0.40388059 0.17138532 ... 0.1116602  0.10949086 0.1223522 ]
#  [0.98334084 1.48438639 1.45554871 ... 0.1116602  0.10949086 0.1223522 ]
#  ...
#  [0.3775124  1.48438639 1.78093552 ... 0.1116602  0.10949086 0.1223522 ]
#  [0.38324333 0.40388059 0.49677212 ... 0.1116602  0.10949086 0.1223522 ]
#  [0.58782203 1.48438639 1.78093552 ... 0.1116602  0.10949086 0.1223522 ]]

# %%
#save new list with z-score < 3
df_ohe_out = df_ohe[(zFP<3).all(axis=1)]
df_ohe_out
# Out:
#           price  bedrooms  ...  zipcode_98177  zipcode_98199
# 0      221900.0         3  ...              0              0
# 2      180000.0         2  ...              0              0
# 6      257500.0         3  ...              0              0
# 12     310000.0         3  ...              0              0
# 16     395000.0         3  ...              0              0
# ...         ...       ...  ...            ...            ...
# 21549  341780.0         4  ...              0              0
# 21569  270000.0         3  ...              0              0
# 21575  572000.0         4  ...              0              0
# 21578  350000.0         4  ...              0              0
# 21582  541800.0         4  ...              0              0
#
# [4931 rows x 61 columns]

# %% [markdown]
# > Using z-score to remove outliers made our dataset much smaller. Lets look at IQR to see if there is a difference.

# %% [markdown]
# ### Using IQR

# %%
#identify the diff quartiles
Q1 = df_ohe['price'].quantile(0.25)
Q3 = df_ohe['price'].quantile(0.75)
IQR = Q3-Q1
print(IQR)
# Out:
# 322500.0

# %%
Lower_Whisker = Q1-1.5*IQR
Upper_Whisker = Q3+1.5*IQR
print(Lower_Whisker, Upper_Whisker)
# Out:
# -161250.0 1128750.0

# %%
test = df_ohe[~((df_ohe['price'] < (Q1 - 1.5 * IQR)) |(df_ohe['price'] > (Q3 + 1.5 * IQR)))]
print(test.shape)
# Out:
# (20211, 61)

# %%
df_ohe.shape
# Out:
# (21357, 61)

# %%
test.shape
# Out:
# (20211, 61)

# %%
sns.boxplot(df_ohe['price'])
# Out:
# <AxesSubplot:xlabel='price'>

# %%
sns.boxplot(test['price'])
# Out:
# <AxesSubplot:xlabel='price'>

# %% [markdown]
# > Using IQR dropped more numbers than using the z-score.
#
# - Used same code and when back to only drop price.

# %% [markdown]
# > **Thoughts**:
# I don't think I want to drop outliers for every column? The only outlier that I think I really need to be concerned with is price. Went back through IQR and dropped only price.

# %%
df_ohe.describe()
# Out:
#               price      bedrooms  ...  zipcode_98177  zipcode_98199
# count  2.135700e+04  21357.000000  ...   21357.000000   21357.000000
# mean   5.404997e+05      3.373788  ...       0.011846       0.014749
# std    3.666157e+05      0.925514  ...       0.108196       0.120550
# min    7.800000e+04      1.000000  ...       0.000000       0.000000
# 25%    3.225000e+05      3.000000  ...       0.000000       0.000000
# 50%    4.500000e+05      3.000000  ...       0.000000       0.000000
# 75%    6.450000e+05      4.000000  ...       0.000000       0.000000
# max    7.700000e+06     33.000000  ...       1.000000       1.000000
#
# [8 rows x 61 columns]

# %%
test.describe()
# Out:
#               price      bedrooms  ...  zipcode_98177  zipcode_98199
# count  2.021100e+04  20211.000000  ...   20211.000000   20211.000000
# mean   4.769666e+05      3.331503  ...       0.011330       0.013409
# std    2.079344e+05      0.907414  ...       0.105843       0.115019
# min    7.800000e+04      1.000000  ...       0.000000       0.000000
# 25%    3.150000e+05      3.000000  ...       0.000000       0.000000
# 50%    4.375000e+05      3.000000  ...       0.000000       0.000000
# 75%    6.000000e+05      4.000000  ...       0.000000       0.000000
# max    1.120000e+06     33.000000  ...       1.000000       1.000000
#
# [8 rows x 61 columns]

# %% [markdown]
# Choosing to drop outliers on bedroom, since there is one with 30 bedrooms.

# %%
def IQR_removal(col, test):
    Q1 = test[col].quantile(0.25)
    Q3 = test[col].quantile(0.75)
    IQR = Q3-Q1
    print(IQR)

    num_rows = len(test)
    test = test[~((test[col] < (Q1 - 1.5 * IQR)) |(test[col] > (Q3 + 1.5 * IQR)))]
    num_outliers = num_rows - len(test)
    print(test.shape)
    print(f"Number of outliers removed from {col}: {num_outliers}")
    return test

# %%
test = IQR_removal('bedrooms', test)
# Out:
# 1.0
# (19757, 61)
# Number of outliers removed from bedrooms: 454

# %%
test = IQR_removal('sqft_lot', test)
# Out:
# 5300.0
# (17603, 61)
# Number of outliers removed from sqft_lot: 2154

# %%
test = IQR_removal('grade', test)
# Out:
# 1.0
# (16854, 61)
# Number of outliers removed from grade: 749

# %%
test = IQR_removal('bathrooms', test)
# Out:
# 1.0
# (16832, 61)
# Number of outliers removed from bathrooms: 22

# %%
#Made numbers worse
#test = IQR_removal('view', test)

# %%
#No positive impact. Leaving in.
#test = IQR_removal('yr_built', test)

# %%
#made multicollinearity worse
#test = IQR_removal('yr_renovated', test)

# %%
test = IQR_removal('sqft_living15', test)
# Out:
# 710.0
# (16575, 61)
# Number of outliers removed from sqft_living15: 257

# %% [markdown]
# # Model

# %% [markdown]
# ### R-squared Modeling

# %% [markdown]
# > Originally only dropped price outliers to see what difference it made. Went back and added bedrooms as well.

# %%
features = '+'.join(test.drop(columns= 'price').columns)
features
# Out:
# 'bedrooms+bathrooms+sqft_lot+floors+waterfront+view+grade+yr_built+yr_renovated+lat+sqft_living15+zipcode_98002+zipcode_98004+zipcode_98005+zipcode_98006+zipcode_98007+zipcode_98008+zipcode_98010+zipcode_98022+zipcode_98023+zipcode_98024+zipcode_98027+zipcode_98029+zipcode_98033+zipcode_98034+zipcode_98038+zipcode_98039+zipcode_98040+zipcode_98045+zipcode_98052+zipcode_98053+zipcode_98056+zipcode_98059+zipcode_98065+zipcode_98072+zipcode_98074+zipcode_98075+zipcode_98102+zipcode_98103+zipcode_98105+zipcode_98106+zipcode_98107+zipcode_98108+zipcode_98109+zipcode_98112+zipcode_98115+zipcode_98116+zipcode_98117+zipcode_98118+zipcode_98119+zipcode_98122+zipcode_98125+zipcode_98126+zipcode_98133+zipcode_98136+zipcode_98144+zipcode_98146+zipcode_98168+zipcode_98177+zipcode_98199'

# %%
formula = target + '~' + features
model = smf.ols(formula, test).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.786
# Model:                            OLS   Adj. R-squared:                  0.786
# Method:                 Least Squares   F-statistic:                     1014.
# Date:                Tue, 01 Sep 2020   Prob (F-statistic):               0.00
# Time:                        09:47:50   Log-Likelihood:            -2.1209e+05
# No. Observations:               16575   AIC:                         4.243e+05
# Df Residuals:                   16514   BIC:                         4.248e+05
# Df Model:                          60
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept     -1.218e+07   4.01e+05    -30.375      0.000    -1.3e+07   -1.14e+07
# bedrooms       2.003e+04   1057.530     18.942      0.000     1.8e+04    2.21e+04
# bathrooms      4.425e+04   1583.804     27.936      0.000    4.11e+04    4.73e+04
# sqft_lot          3.6415      0.284     12.824      0.000       3.085       4.198
# floors         5969.6254   1802.658      3.312      0.001    2436.221    9503.030
# waterfront     2.468e+05   2.02e+04     12.206      0.000    2.07e+05    2.86e+05
# view           3.482e+04   1300.538     26.773      0.000    3.23e+04    3.74e+04
# grade          6.306e+04   1282.804     49.158      0.000    6.05e+04    6.56e+04
# yr_built      -1096.0197     38.424    -28.524      0.000   -1171.335   -1020.705
# yr_renovated     14.7436      2.091      7.051      0.000      10.645      18.842
# lat            2.923e+05   8214.954     35.585      0.000    2.76e+05    3.08e+05
# sqft_living15    72.0370      2.007     35.894      0.000      68.103      75.971
# zipcode_98002  2.922e+04   6930.915      4.215      0.000    1.56e+04    4.28e+04
# zipcode_98004  4.125e+05   8020.626     51.431      0.000    3.97e+05    4.28e+05
# zipcode_98005  2.446e+05   8683.055     28.165      0.000    2.28e+05    2.62e+05
# zipcode_98006  1.917e+05   5377.659     35.639      0.000    1.81e+05    2.02e+05
# zipcode_98007  1.487e+05   8458.730     17.577      0.000    1.32e+05    1.65e+05
# zipcode_98008  1.452e+05   5850.596     24.817      0.000    1.34e+05    1.57e+05
# zipcode_98010  8.908e+04   1.42e+04      6.295      0.000    6.13e+04    1.17e+05
# zipcode_98022  4.587e+04   7884.761      5.817      0.000    3.04e+04    6.13e+04
# zipcode_98023 -1.483e+04   4607.640     -3.219      0.001   -2.39e+04   -5800.709
# zipcode_98024   5.75e+04   1.87e+04      3.069      0.002    2.08e+04    9.42e+04
# zipcode_98027  1.548e+05   6493.333     23.846      0.000    1.42e+05    1.68e+05
# zipcode_98029  1.569e+05   5673.717     27.648      0.000    1.46e+05    1.68e+05
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4152.172
# Skew:                           0.498   Prob(JB):                         0.00
# Kurtosis:                       5.241   Cond. No.                     4.87e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.87e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# > **Dropping Price Outliers**:
# - multicollinearity dropped to 2.43e+07
# - R2 value rose to .796
#
# >**Removing Bedrooms Outliers**:
# - multi = 2.41e+07
# - R2 .798
#
# > **Removing Sqft_lot Outliers**:
# - multi = 5.00e+06
# - R2 = .807
#
# >**Removing Grade Outliers**:
# - multi =4.89e+06
# - R2 = .794
#
# >**Removing Bathroom Outliers**:
# - multi =4.88e+06
# - R2 = .793
#
# > **Removing View Outliers**:
# - multi = 1.09e+16
# - R2 = .789
# - Made numbers worse therefore leaving in data.
#
# >**Yr_Built**
# - multi = 4.90e+06
# - R2 = .793
# - No positive impact. Leaving in data.
#
# >**Sqft_Living**
# - multi = 4.87e+06
# - R2 = .786

# %% [markdown]
# ### Answer to Question:

# %% [markdown]
# **Question**: Does removing outliers impact my model?
#
# > Answer: When I first removed all the outliers in the dataset I was left with hardly anything to work with. (about 4000 rows) When I went back and only removed the outliers for price my R2 value rose and my multicollinearity dropped. This shows that removing outliers do have an impact on models and it is in the hands of the data scientist to make the correct choices.

# %%
p_val_removal(test)

# %%
features = '+'.join(test.drop(columns= 'price').columns)
features
# Out:
# 'bedrooms+bathrooms+sqft_lot+floors+waterfront+view+grade+yr_built+yr_renovated+lat+sqft_living15+zipcode_98002+zipcode_98004+zipcode_98005+zipcode_98006+zipcode_98007+zipcode_98008+zipcode_98010+zipcode_98022+zipcode_98023+zipcode_98024+zipcode_98027+zipcode_98029+zipcode_98033+zipcode_98034+zipcode_98038+zipcode_98039+zipcode_98040+zipcode_98045+zipcode_98052+zipcode_98053+zipcode_98056+zipcode_98059+zipcode_98065+zipcode_98072+zipcode_98074+zipcode_98075+zipcode_98102+zipcode_98103+zipcode_98105+zipcode_98106+zipcode_98107+zipcode_98108+zipcode_98109+zipcode_98112+zipcode_98115+zipcode_98116+zipcode_98117+zipcode_98118+zipcode_98119+zipcode_98122+zipcode_98125+zipcode_98126+zipcode_98133+zipcode_98136+zipcode_98144+zipcode_98146+zipcode_98177+zipcode_98199'

# %%
formula = target + '~' + features
model = smf.ols(formula, test).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.786
# Model:                            OLS   Adj. R-squared:                  0.786
# Method:                 Least Squares   F-statistic:                     1031.
# Date:                Tue, 01 Sep 2020   Prob (F-statistic):               0.00
# Time:                        09:47:51   Log-Likelihood:            -2.1209e+05
# No. Observations:               16575   AIC:                         4.243e+05
# Df Residuals:                   16515   BIC:                         4.248e+05
# Df Model:                          59
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept     
# zipcode_98106  5.335e+04   5303.275     10.061      0.000     4.3e+04    6.37e+04
# zipcode_98107  1.971e+05   6226.036     31.650      0.000    1.85e+05    2.09e+05
# zipcode_98108  4.873e+04   6896.492      7.066      0.000    3.52e+04    6.22e+04
# zipcode_98109  2.936e+05   1.02e+04     28.927      0.000    2.74e+05    3.14e+05
# zipcode_98112  3.166e+05   7555.644     41.903      0.000    3.02e+05    3.31e+05
# zipcode_98115  2.045e+05   4622.498     44.245      0.000    1.95e+05    2.14e+05
# zipcode_98116  2.154e+05   5585.480     38.562      0.000    2.04e+05    2.26e+05
# zipcode_98117  2.002e+05   4785.647     41.835      0.000    1.91e+05     2.1e+05
# zipcode_98118  9.387e+04   4533.331     20.707      0.000     8.5e+04    1.03e+05
# zipcode_98119  2.834e+05   7795.430     36.359      0.000    2.68e+05    2.99e+05
# zipcode_98122  1.978e+05   6151.741     32.145      0.000    1.86e+05     2.1e+05
# zipcode_98125  7.111e+04   5163.884     13.771      0.000     6.1e+04    8.12e+04
# zipcode_98126  1.321e+05   5238.761     25.207      0.000    1.22e+05    1.42e+05
# zipcode_98133  2.917e+04   4816.144      6.056      0.000    1.97e+04    3.86e+04
# zipcode_98136  1.851e+05   6020.152     30.753      0.000    1.73e+05    1.97e+05
# zipcode_98144   1.55e+05   5634.897     27.515      0.000    1.44e+05    1.66e+05
# zipcode_98146  5.658e+04   5799.836      9.756      0.000    4.52e+04     6.8e+04
# zipcode_98177  7.806e+04   6792.985     11.491      0.000    6.47e+04    9.14e+04
# zipcode_98199  2.549e+05   6089.666     41.851      0.000    2.43e+05    2.67e+05
# ==============================================================================
# Omnibus:                     1483.947   Durbin-Watson:                   1.964
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4149.180
# Skew:                           0.497   Prob(JB):                         0.00
# Kurtosis:                       5.240   Cond. No.                     4.87e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.87e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# > **Observations**:
# - R2 stayed the same .786
# - Pvalues taken care of
# - Multicollinearity dropped to 4.87e_06

# %%
create_visuals(test[target])

# %%
X = test.drop('price', axis=1)
X = sm.add_constant(X)
X.shape
# Out:
# (16575, 60)

# %%
vif = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]

# %%
vif_results = pd.Series(dict(zip(X.columns, vif)))
vif_results
# Out:
# const            348738.374110
# bedrooms              1.470847
# bathrooms             2.332002
# sqft_lot              2.029772
# floors                2.083960
# waterfront            1.068024
# view                  1.198283
# grade                 2.295944
# yr_built              2.791254
# yr_renovated          1.092221
# lat                   2.870791
# sqft_living15         2.128721
# zipcode_98002         1.079203
# zipcode_98004         1.050756
# zipcode_98005         1.047567
# zipcode_98006         1.097733
# zipcode_98007         1.039861
# zipcode_98008         1.090871
# zipcode_98010         1.018556
# zipcode_98022         1.119189
# zipcode_98023         1.183175
# zipcode_98024         1.008387
# zipcode_98027         1.050418
# zipcode_98029         1.112681
# zipcode_98033         1.166453
# zipcode_98034         1.323646
# zipcode_98038         1.161730
# zipcode_98039         1.002623
# zipcode_98040         1.051368
# zipcode_98045         1.032164
# zipcode_98052         1.250419
# zipcode_98053         1.156947
# zipcode_98056         1.056790
# zipcode_98059         1.077061
# zipcode_98065         1.086459
# zipcode_98072         1.112221
# zipcode_98074         1.122727
# zipcode_98075         1.059822
# zipcode_98102         1.091326
# zipcode_98103         1.577048
# zipcode_98105         1.173004
# zipcode_98106         1.112010
# zipcode_98107         1.248471
# zipcode_98108         1.071120
# zipcode_98109         1.086240
# zipcode_98112         1.153922
# zipcode_98115         1.426091
# zipcode_98116         1.178451
# zipcode_98117         1.458291
# zipcode_98118         1.184443
# zipcode_98119         1.158095
# zipcode_98122         1.223654
# zipcode_98125         1.265060
# zipcode_98126         1.164502
# zipcode_98133         1.371227
# zipcode_98136         1.112055
# zipcode_98144         1.195390
# zipcode_98146         1.057782
# zipcode_98177         1.163140
# zipcode_98199         1.180264
# dtype: float64

# %%
threshold = 6
bad_vif2 = list(vif_results[vif_results>threshold].index)
if 'const' in bad_vif2:
    bad_vif2.remove('const') 
bad_vif2
# Out:
# []

# %%
test.describe()
# Out:
#               price      bedrooms  ...  zipcode_98177  zipcode_98199
# count  1.657500e+04  16575.000000  ...   16575.000000   16575.000000
# mean   4.515062e+05      3.271614  ...       0.011765       0.014902
# std    1.888829e+05      0.778900  ...       0.107829       0.121164
# min    8.200000e+04      2.000000  ...       0.000000       0.000000
# 25%    3.059750e+05      3.000000  ...       0.000000       0.000000
# 50%    4.180000e+05      3.000000  ...       0.000000       0.000000
# 75%    5.600000e+05      4.000000  ...       0.000000       0.000000
# max    1.120000e+06      5.000000  ...       1.000000       1.000000
#
# [8 rows x 60 columns]

# %%
create_visuals(test[target])

# %% [markdown]
# # Try Log Transformation

# %%
test.columns
# Out:
# Index(['price', 'bedrooms', 'bathrooms', 'sqft_lot', 'floors', 'waterfront',
#        'view', 'grade', 'yr_built', 'yr_renovated', 'lat', 'sqft_living15',
#        'zipcode_98002', 'zipcode_98004', 'zipcode_98005', 'zipcode_98006',
#        'zipcode_98007', 'zipcode_98008', 'zipcode_98010', 'zipcode_98022',
#        'zipcode_98023', 'zipcode_98024', 'zipcode_98027', 'zipcode_98029',
#        'zipcode_98033', 'zipcode_98034', 'zipcode_98038', 'zipcode_98039',
#        'zipcode_98040', 'zipcode_98045', 'zipcode_98052', 'zipcode_98053',
#        'zipcode_98056', 'zipcode_98059', 'zipcode_98065', 'zipcode_98072',
#        'zipcode_98074', 'zipcode_98075', 'zipcode_98102', 'zipcode_98103',
#        'zipcode_98105', 'zipcode_98106', 'zipcode_98107', 'zipcode_98108',
#        'zipcode_98109', 'zipcode_98112', 'zipcode_98115', 'zipcode_98116',
#        'zipcode_98117', 'zipcode_98118', 'zipcode_98119', 'zipcode_98122',
#        'zipcode_98125', 'zipcode_98126', 'zipcode_98133', 'zipcode_98136',
#        'zipcode_98144', 'zipcode_98146', 'zipcode_98177', 'zipcode_98199'],
#       dtype='object')

# %%
cols = ['bedrooms', 'bathrooms', 'sqft_lot', 'floors', 'waterfront',
       'view', 'grade', 'yr_built', 'yr_renovated', 'lat', 'sqft_living15']

# %%
pd.plotting.scatter_matrix(test[cols], figsize= (10,12));

# %%
#sqft_living15, grade - .823
non_normal = ['bedrooms', 'bathrooms', 'sqft_lot', 'floors', 'lat', 'yr_built', 'sqft_living15', 'grade']
for feat in non_normal:
    test[feat] = test[feat].map(lambda x: np.log(x))
pd.plotting.scatter_matrix(test[cols], figsize=(10,12));

# %%
features = '+'.join(test.drop(columns= 'price').columns)
features
# Out:
# 'bedrooms+bathrooms+sqft_lot+floors+waterfront+view+grade+yr_built+yr_renovated+lat+sqft_living15+zipcode_98002+zipcode_98004+zipcode_98005+zipcode_98006+zipcode_98007+zipcode_98008+zipcode_98010+zipcode_98022+zipcode_98023+zipcode_98024+zipcode_98027+zipcode_98029+zipcode_98033+zipcode_98034+zipcode_98038+zipcode_98039+zipcode_98040+zipcode_98045+zipcode_98052+zipcode_98053+zipcode_98056+zipcode_98059+zipcode_98065+zipcode_98072+zipcode_98074+zipcode_98075+zipcode_98102+zipcode_98103+zipcode_98105+zipcode_98106+zipcode_98107+zipcode_98108+zipcode_98109+zipcode_98112+zipcode_98115+zipcode_98116+zipcode_98117+zipcode_98118+zipcode_98119+zipcode_98122+zipcode_98125+zipcode_98126+zipcode_98133+zipcode_98136+zipcode_98144+zipcode_98146+zipcode_98177+zipcode_98199'

# %%
formula = target + '~' + features
model = smf.ols(formula, test).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.787
# Model:                            OLS   Adj. R-squared:                  0.786
# Method:                 Least Squares   F-statistic:                     1032.
# Date:                Tue, 01 Sep 2020   Prob (F-statistic):               0.00
# Time:                        09:49:12   Log-Likelihood:            -2.1209e+05
# No. Observations:               16575   AIC:                         4.243e+05
# Df Residuals:                   16515   BIC:                         4.248e+05
# Df Model:                          59
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept     -4.562e+07   1.65e+06    -27.647      0.000   -4.89e+07   -4.24e+07
# bedrooms       5.426e+04   3423.752     15.849      0.000    4.76e+04     6.1e+04
# bathrooms      6.818e+04   2826.415     24.123      0.000    6.26e+04    7.37e+04
# sqft_lot       5.359e+04   1908.844     28.074      0.000    4.98e+04    5.73e+04
# floors          4.09e+04   2799.510     14.609      0.000    3.54e+04    4.64e+04
# waterfront     2.416e+05   2.02e+04     11.956      0.000    2.02e+05    2.81e+05
# view            3.77e+04   1295.857     29.094      0.000    3.52e+04    4.02e+04
# grade          4.547e+05   9471.204     48.009      0.000    4.36e+05    4.73e+05
# yr_built      -1.568e+06   7.74e+04    -20.246      0.000   -1.72e+06   -1.42e+06
# yr_renovated     15.9411      2.088      7.633      0.000      11.848      20.035
# lat            1.439e+07    3.9e+05     36.883      0.000    1.36e+07    1.52e+07
# sqft_living15  1.058e+05   3650.694     28.972      0.000    9.86e+04    1.13e+05
# zipcode_98002  3.324e+04   6924.355      4.801      0.000    1.97e+04    4.68e+04
# zipcode_98004  4.226e+05   8020.846     52.683      0.000    4.07e+05    4.38e+05
# zipcode_98005  2.555e+05   8677.408     29.445      0.000    2.38e+05    2.73e+05
# zipcode_98006  2.012e+05   5366.259     37.489      0.000    1.91e+05    2.12e+05
# zipcode_98007   1.53e+05   8454.389     18.100      0.000    1.36e+05     1.7e+05
# zipcode_98008  1.504e+05   5849.500     25.717      0.000    1.39e+05    1.62e+05
# zipcode_98010  7.962e+04   1.41e+04      5.630      0.000    5.19e+04    1.07e+05
# zipcode_98133  3.573e+04   4817.620      7.417      0.000    2.63e+04    4.52e+04
# zipcode_98136  2.047e+05   6056.365     33.791      0.000    1.93e+05    2.17e+05
# zipcode_98144  1.859e+05   5761.212     32.272      0.000    1.75e+05    1.97e+05
# zipcode_98146  6.283e+04   5801.005     10.830      0.000    5.15e+04    7.42e+04
# zipcode_98177  8.556e+04   6793.892     12.594      0.000    7.22e+04    9.89e+04
# zipcode_98199  2.776e+05   6124.485     45.328      0.000    2.66e+05     2.9e+05
# ==============================================================================
# Omnibus:                     1446.618   Durbin-Watson:                   1.960
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3769.279
# Skew:                           0.506   Prob(JB):                         0.00
# Kurtosis:                       5.106   Cond. No.                     8.58e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 8.58e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
create_visuals(test[target])

# %% [markdown]
# > **Last observations for comparison**:
# - R2 stayed the same .786
# - Pvalues taken care of
# - Multicollinearity dropped to 4.87e_06
#
# >**Now**
# - R2 is .787
# - Pvalues are still good
# - Multicollinearity dropped to 8.58e+05

# %% [markdown]
# ### Regression Model Validation

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

# %%
df_train, df_test = train_test_split(test)

# %%
df_train.shape, df_test.shape
# Out:
# ((12431, 60), (4144, 60))

# %% [markdown]
# Next do model summary using training summary

# %%
features = '+'.join(df_train.drop(columns= 'price').columns)
features
# Out:
# 'bedrooms+bathrooms+sqft_lot+floors+waterfront+view+grade+yr_built+yr_renovated+lat+sqft_living15+zipcode_98002+zipcode_98004+zipcode_98005+zipcode_98006+zipcode_98007+zipcode_98008+zipcode_98010+zipcode_98022+zipcode_98023+zipcode_98024+zipcode_98027+zipcode_98029+zipcode_98033+zipcode_98034+zipcode_98038+zipcode_98039+zipcode_98040+zipcode_98045+zipcode_98052+zipcode_98053+zipcode_98056+zipcode_98059+zipcode_98065+zipcode_98072+zipcode_98074+zipcode_98075+zipcode_98102+zipcode_98103+zipcode_98105+zipcode_98106+zipcode_98107+zipcode_98108+zipcode_98109+zipcode_98112+zipcode_98115+zipcode_98116+zipcode_98117+zipcode_98118+zipcode_98119+zipcode_98122+zipcode_98125+zipcode_98126+zipcode_98133+zipcode_98136+zipcode_98144+zipcode_98146+zipcode_98177+zipcode_98199'

# %%
formula = target + '~' + features
model = smf.ols(formula, df_train).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.787
# Model:                            OLS   Adj. R-squared:                  0.786
# Method:                 Least Squares   F-statistic:                     773.7
# Date:                Tue, 01 Sep 2020   Prob (F-statistic):               0.00
# Time:                        09:49:13   Log-Likelihood:            -1.5910e+05
# No. Observations:               12431   AIC:                         3.183e+05
# Df Residuals:                   12371   BIC:                         3.188e+05
# Df Model:                          59
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept     -4.497e+07   1.91e+06    -23.548      0.000   -4.87e+07   -4.12e+07
# bedrooms       5.511e+04   3960.878     13.914      0.000    4.73e+04    6.29e+04
# bathrooms      6.929e+04   3263.330     21.232      0.000    6.29e+04    7.57e+04
# sqft_lot       5.375e+04   2212.976     24.289      0.000    4.94e+04    5.81e+04
# floors         4.032e+04   3248.506     12.412      0.000     3.4e+04    4.67e+04
# waterfront     2.521e+05   2.21e+04     11.396      0.000    2.09e+05    2.95e+05
# zipcode_98107  2.339e+05   7301.789     32.039      0.000     2.2e+05    2.48e+05
# zipcode_98108  6.814e+04   7967.077      8.552      0.000    5.25e+04    8.38e+04
# zipcode_98109  3.369e+05   1.18e+04     28.440      0.000    3.14e+05     3.6e+05
# zipcode_98112  3.563e+05   9077.514     39.256      0.000    3.39e+05    3.74e+05
# zipcode_98115  2.218e+05   5347.767     41.469      0.000    2.11e+05    2.32e+05
# zipcode_98116  2.399e+05   6613.759     36.279      0.000    2.27e+05    2.53e+05
# zipcode_98117  2.269e+05   5524.376     41.070      0.000    2.16e+05    2.38e+05
# zipcode_98118  1.135e+05   5268.717     21.550      0.000    1.03e+05    1.24e+05
# zipcode_98119  3.325e+05   9201.300     36.133      0.000    3.14e+05    3.51e+05
# zipcode_98122  2.317e+05   7335.863     31.584      0.000    2.17e+05    2.46e+05
# zipcode_98125  8.076e+04   5949.665     13.574      0.000    6.91e+04    9.24e+04
# zipcode_98126  1.545e+05   6120.612     25.249      0.000    1.43e+05    1.67e+05
# zipcode_98133  3.504e+04   5579.230      6.280      0.000    2.41e+04     4.6e+04
# zipcode_98136  2.052e+05   6850.567     29.957      0.000    1.92e+05    2.19e+05
# zipcode_98144  1.883e+05   6637.397     28.371      0.000    1.75e+05    2.01e+05
# zipcode_98146  6.934e+04   6850.583     10.121      0.000    5.59e+04    8.28e+04
# zipcode_98177  9.375e+04   7970.464     11.763      0.000    7.81e+04    1.09e+05
# zipcode_98199  2.784e+05   7180.866     38.766      0.000    2.64e+05    2.92e+05
# ==============================================================================
# Omnibus:                     1085.652   Durbin-Watson:                   1.994
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2768.169
# Skew:                           0.512   Prob(JB):                         0.00
# Kurtosis:                       5.073   Cond. No.                     8.58e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 8.58e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
y_train_pred = model.predict(df_train)
y_train_pred
# Out:
# 4150     587195.548903
# 9698     233653.669749
# 6888     279124.345225
# 10613    479068.246579
# 5400     427069.184189
#              ...
# 5686     313736.926651
# 2063      45626.139863
# 775      581750.799660
# 18121    569276.339044
# 2327     465955.745899
# Length: 12431, dtype: float64

# %%
y_test_pred = model.predict(df_test)
y_test_pred
# Out:
# 18215    526904.445908
# 8343     254102.406996
# 14264    394849.494705
# 17825    328204.747334
# 15886    803979.664548
#              ...
# 17031    375975.378268
# 4049     522532.445148
# 18907    465647.993450
# 1440     454155.967231
# 15445    403002.623278
# Length: 4144, dtype: float64

# %%
r2_train = r2_score(df_train['price'], y_train_pred)
r2_test = r2_score(df_test['price'], y_test_pred)
#want close scores,should be same as models above

print(f"Training Score: {r2_train}")
print(f"Test Score: {r2_test}")
# Out:
# Training Score: 0.7867778164721688
# Test Score: 0.7851851744967075

# %% [markdown]
# > Numbers should be close to the same.

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.787
# Model:                            OLS   Adj. R-squared:                  0.786
# Method:                 Least Squares   F-statistic:                     773.7
# Date:                Tue, 01 Sep 2020   Prob (F-statistic):               0.00
# Time:                        09:49:14   Log-Likelihood:            -1.5910e+05
# No. Observations:               12431   AIC:                         3.183e+05
# Df Residuals:                   12371   BIC:                         3.188e+05
# Df Model:                          59
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept     
# zipcode_98075  1.715e+05   9395.740     18.254      0.000    1.53e+05     1.9e+05
# zipcode_98102  3.291e+05   1.15e+04     28.676      0.000    3.07e+05    3.52e+05
# zipcode_98103  2.351e+05   5603.134     41.963      0.000    2.24e+05    2.46e+05
# zipcode_98105  2.826e+05   8396.246     33.653      0.000    2.66e+05    2.99e+05
# zipcode_98106   7.35e+04   6244.300     11.771      0.000    6.13e+04    8.57e+04
# zipcode_98107  2.339e+05   7301.789     32.039      0.000     2.2e+05    2.48e+05
# zipcode_98108  6.814e+04   7967.077      8.552      0.000    5.25e+04    8.38e+04
# zipcode_98109  3.369e+05   1.18e+04     28.440      0.000    3.14e+05     3.6e+05
# zipcode_98112  3.563e+05   9077.514     39.256      0.000    3.39e+05    3.74e+05
# zipcode_98115  2.218e+05   5347.767     41.469      0.000    2.11e+05    2.32e+05
# zipcode_98116  2.399e+05   6613.759     36.279      0.000    2.27e+05    2.53e+05
# zipcode_98117  2.269e+05   5524.376     41.070      0.000    2.16e+05    2.38e+05
# zipcode_98118  1.135e+05   5268.717     21.550      0.000    1.03e+05    1.24e+05
# zipcode_98119  3.325e+05   9201.300     36.133      0.000    3.14e+05    3.51e+05
# zipcode_98122  2.317e+05   7335.863     31.584      0.000    2.17e+05    2.46e+05
# zipcode_98125  8.076e+04   5949.665     13.574      0.000    6.91e+04    9.24e+04
# zipcode_98126  1.545e+05   6120.612     25.249      0.000    1.43e+05    1.67e+05
# zipcode_98133  3.504e+04   5579.230      6.280      0.000    2.41e+04     4.6e+04
# zipcode_98136  2.052e+05   6850.567     29.957      0.000    1.92e+05    2.19e+05
# zipcode_98144  1.883e+05   6637.397     28.371      0.000    1.75e+05    2.01e+05
# zipcode_98146  6.934e+04   6850.583     10.121      0.000    5.59e+04    8.28e+04
# zipcode_98177  9.375e+04   7970.464     11.763      0.000    7.81e+04    1.09e+05
# zipcode_98199  2.784e+05   7180.866     38.766      0.000    2.64e+05    2.92e+05
# ==============================================================================
# Omnibus:                     1085.652   Durbin-Watson:                   1.994
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2768.169
# Skew:                           0.512   Prob(JB):                         0.00
# Kurtosis:                       5.073   Cond. No.                     8.58e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 8.58e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
create_visuals(df_train[target])

# %% [markdown]
# >**Observations**:
# - R2 is the same.
# - Test multicollinearity number is slightly lower than mine.

# %% [markdown]
# # Interpret

# %%
def color_negative(val):
    color = "red" if val < 0 else 'black'
    return 'color: %s' % color

# %%
coeffs = model.params.sort_values(ascending=False)
#if you increase by one thats the increase in selling point. 
coeffs.sort_index().to_frame('Coefficients').style.applymap(color_negative)
# Out:
# <style  type="text/css" >
#     #T_ed74717a_ec59_11ea_89b8_d0817a9db666row0_col0 {
#             color:  red;
#         }    #T_ed74717a_ec59_11ea_89b8_d0817a9db666row1_col0 {
#             color:  black;
#         }    #T_ed74717a_ec59_11ea_89b8_d0817a9db666row2_col0 {
#             color:  black;
#         }    #T_ed74717a_ec59_11ea_89b8_d0817a9db666row3_col0 {
#             color:  black;
#         }    #T_ed74717a_ec59_11ea_89b8_d0817a9db666row4_col0 {
#             color:  black;
#         }    #T_ed74717a_ec59_11ea_89b8_d0817a9db666row5_col0 {
#             color:  black;
#         }    #T_ed74717a_ec59_11ea_89b8_d0817a9db666row6_col0 {
#             color:  black;
#         }    #T_ed74717a_ec59_11ea_89b8_d0817a9db666row7_col0 {
#             color:  black;
#         }    #T_ed74717a_ec59_11ea_89b8_d0817a9db666row8_col0 {
#             color:  black;
#         }    #T_ed74717a_ec59_11ea_89b8_d0817a9db666row9_col0 {
#             color:  black;
#         }    #T_ed74717a_ec59_11ea_89b8_d0817a9db666row10_col0 {
#             color:  red;
#         }    #T_ed74717a_ec59_11ea_89b8_d0817a9db666row11_col0 {
#             color:  black;
#         }    #T_ed74717a_ec59_11ea_89b8_d0817a9db666row12_col0 {
#             color:  black;
#         }    #T_ed74717a_ec59_11ea_89b8_d0817a9db666row13_col0 {
#             color:  black;
#         }    #T_ed74717a_ec59_11ea_89b8_d0817a9db666row14_col0 {
#             color:  black;
#         }    #T_ed74717a_ec59_11ea_89b8_d0817a9db666row15_col0 {
#             color:  black;
#         }    #T_ed74717a_ec59_11ea_89b8_d0817a9db666row16_col0 {
#             color:  black;
#         }    #T_ed74717a_ec59_11ea_89b8_d0817a9db666row17_col0 {
#             color:  black;
#         }    #T_ed74717a_ec59_11ea_89b8_d0817a9db666row18_col0 {
#             color:  black;
#         }    #T_ed74717a_ec59_11ea_89b8_d0817a9db666row19_col0 {
#             color:  black;
#         }    #T_ed74717a_ec59_11ea_89b8_d0817a9db666row20_col0 {
#             color:  red;
#         }    #T_ed74717a_ec59_11ea_89b8_d0817a9db666row21_col0 {
#             color:  black;
#         }    #T_ed74717a_ec59_11ea_89b8_d0817a9db666row22_col0 {
#             color:  black;
#         }    #T_ed74717a_ec59_11ea_89b8_d0817a9db666row23_col0 {
#             color:  black;
#         }    #T_ed74717a_ec59_11ea_89b8_d0817a9db666row24_col0 {
#             color:  black;
#         }    #T_ed74717a_ec59_11ea_89b8_d0817a9db666row25_col0 {
#             color:  black;
#         }    #T_ed74717a_ec59_11ea_89b8_d0817a9db666row26_col0 {
#             color:  black;
#         }    #T_ed74717a_ec59_11ea_89b8_d0817a9db666row27_col0 {
#             color:  black;
#         }    #T_ed74717a_ec59_11ea_89b8_d0817a9db666row28_col0 {
#             color:  black;
#         }    #T_ed74717a_ec59_11ea_89b8_d0817a9db666row29_col0 {
#             color:  black;
#         }    #T_ed74717a_ec59_11ea_89b8_d0817a9db666row30_col0 {
#             color:  black;
#         }    #T_ed74717a_ec59_11ea_89b8_d0817a9db666row31_col0 {
#             color:  black;
#         }    #T_ed74717a_ec59_11ea_89b8_d0817a9db666row32_col0 {
#             color:  black;
#         }    #T_ed74717a_ec59_11ea_89b8_d0817a9db666row33_col0 {
#             color:  black;
#         }    #T_ed74717a_ec59_11ea_89b8_d0817a9db666row34_col0 {
#             color:  black;
#         }    #T_ed74717a_ec59_11ea_89b8_d0817a9db666row35_col0 {
#             color:  black;
#         }    #T_ed74717a_ec59_11ea_89b8_d0817a9db666row36_col0 {
#             color:  black;
#         }    #T_ed74717a_ec59_11ea_89b8_d0817a9db666row37_col0 {
#             color:  black;
#         }    #T_ed74717a_ec59_11ea_89b8_d0817a9db666row38_col0 {
#             color:  black;
#         }    #T_ed74717a_ec59_11ea_89b8_d0817a9db666row39_col0 {
#             color:  black;
#         }    #T_ed74717a_ec59_11ea_89b8_d0817a9db666row40_col0 {
#             color:  black;
#         }    #T_ed74717a_ec59_11ea_89b8_d0817a9db666row41_col0 {
#             color:  black;
#         }    #T_ed74717a_ec59_11ea_89b8_d0817a9db666row42_col0 {
#             color:  black;
#         }    #T_ed74717a_ec59_11ea_89b8_d0817a9db666row43_col0 {
#             color:  black;
#         }    #T_ed74717a_ec59_11ea_89b8_d0817a9db666row44_col0 {
#             color:  black;
#         }    #T_ed74717a_ec59_11ea_89b8_d0817a9db666row45_col0 {
#             color:  black;
#         }    #T_ed74717a_ec59_11ea_89b8_d0817a9db666row46_col0 {
#             color:  black;
#         }    #T_ed74717a_ec59_11ea_89b8_d0817a9db666row47_col0 {
#             color:  black;
#         }    #T_ed74717a_ec59_11ea_89b8_d0817a9db666row48_col0 {
#             color:  black;
#         }    #T_ed74717a_ec59_11ea_89b8_d0817a9db666row49_col0 {
#             color:  black;
#         }    #T_ed74717a_ec59_11ea_89b8_d0817a9db666row50_col0 {
#             color:  black;
#         }    #T_ed74717a_ec59_11ea_89b8_d0817a9db666row51_col0 {
#             color:  black;
#         }    #T_ed74717a_ec59_11ea_89b8_d0817a9db666row52_col0 {
#             color:  black;
#         }    #T_ed74717a_ec59_11ea_89b8_d0817a9db666row53_col0 {
#             color:  black;
#         }    #T_ed74717a_ec59_11ea_89b8_d0817a9db666row54_col0 {
#             color:  black;
#         }    #T_ed74717a_ec59_11ea_89b8_d0817a9db666row55_col0 {
#             color:  black;
#         }    #T_ed74717a_ec59_11ea_89b8_d0817a9db666row56_col0 {
#             color:  black;
#         }    #T_ed74717a_ec59_11ea_89b8_d0817a9db666row57_col0 {
#             color:  black;
#         }    #T_ed74717a_ec59_11ea_89b8_d0817a9db666row58_col0 {
#             color:  black;
#         }    #T_ed74717a_ec59_11ea_89b8_d0817a9db666row59_col0 {
#             color:  black;
#         }</style><table id="T_ed74717a_ec59_11ea_89b8_d0817a9db666" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Coefficients</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ed74717a_ec59_11ea_89b8_d0817a9db666level0_row0" class="row_heading level0 row0" >Intercept</th>
#                         <td id="T_ed74717a_ec59_11ea_89b8_d0817a9db666row0_col0" class="data row0 col0" >-44970751.026605</td>
#             </tr>
#             <tr>
#                         <th id="T_ed74717a_ec59_11ea_89b8_d0817a9db666level0_row1" class="row_heading level0 row1" >bathrooms</th>
#                         <td id="T_ed74717a_ec59_11ea_89b8_d0817a9db666row1_col0" class="data row1 col0" >69287.640606</td>
#             </tr>
#             <tr>
#                         <th id="T_ed74717a_ec59_11ea_89b8_d0817a9db666level0_row2" class="row_heading level0 row2" >bedrooms</th>
#                         <td id="T_ed74717a_ec59_11ea_89b8_d0817a9db666row2_col0" class="data row2 col0" >55112.546329</td>
#             </tr>
#             <tr>
#                         <th id="T_ed74717a_ec59_11ea_89b8_d0817a9db666level0_row3" class="row_heading level0 row3" >floors</th>
#                         <td id="T_ed74717a_ec59_11ea_89b8_d0817a9db666row3_col0" class="data row3 col0" >40321.261539</td>
#             </tr>
#             <tr>
#                         <th id="T_ed74717a_ec59_11ea_89b8_d0817a9db666level0_row4" class="row_heading level0 row4" >grade</th>
#                         <td id="T_ed74717a_ec59_11ea_89b8_d0817a9db666row4_col0" class="data row4 col0" >453725.086188</td>
#             </tr>
#             <tr>
#                         <th id="T_ed74717a_ec59_11ea_89b8_d0817a9db666level0_row5" class="row_heading level0 row5" >lat</th>
#                         <td id="T_ed74717a_ec59_11ea_89b8_d0817a9db666row5_col0" class="data row5 col0" >14206850.189702</td>
#             </tr>
#             <tr>
#                         <th id="T_ed74717a_ec59_11ea_89b8_d0817a9db666level0_row6" class="row_heading level0 row6" >sqft_living15</th>
#                         <td id="T_ed74717a_ec59_11ea_89b8_d0817a9db666row6_col0" class="data row6 col0" >106244.736176</td>
#             </tr>
#             <tr>
#                         <th id="T_ed74717a_ec59_11ea_89b8_d0817a9db666level0_row7" class="row_heading level0 row7" >sqft_lot</th>
#                         <td id="T_ed74717a_ec59_11ea_89b8_d0817a9db666row7_col0" class="data row

# %% [markdown]
# > Grade = classification of construction by quality which refers to thetypes of materials used and the quality of workmanship.

# %%
joint_graphs(test, 'bedrooms', target = 'price')

# %%
@interact 
def show_plot(col=test):
    joint_graphs(test, col)
# Out:
# /Users/laurenesser/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/ops/array_ops.py:253: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   res_values = method(rvalues)
# interactive(children=(Dropdown(description='col', options=('price', 'bedrooms', 'bathrooms', 'sqft_lot', 'floo…

# %% [markdown]
# # Conclusions & Recommendations

# %% [markdown]
# Here I will summarize my conclusions and bullet point my list of recommendations which are based on my modeling results.

# %% [markdown]
# ### top recs?

# %% [markdown]
# > - high grade material
# > - increase number of bathrooms
# > - Waterfront is always a perk
# > - Try to have at least 3 viewings of the house before selling.
# > - If you are buying always consider location. Take a peak at my tableau.
