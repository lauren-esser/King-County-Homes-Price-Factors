# %% [markdown]
# ## Mod 2 Project Submission
#
# Please fill out:
# * Student name: Lauren Esser
# * Student pace: Full time
# * Scheduled project review date/time: Tuesday, Sept 8 at 4:30 pm
# * Instructor name: James Irving
# * Blog post URL: https://lauren-esser.github.io/osemn_is_awesome

# %% [markdown]
# # Abstract

# %% [markdown]
# In the words of Suze Orman “Owning a home is a keystone of wealth…both financial affluence and emotional security.” In this notebook I take a deeper look at the housing market in King County, Washington. What drives success in the market? Should we buy more bedrooms or bathrooms? Does location really matter that much? All of these questions and more are answeredand interpreted within this notebook.
#
# To create this project I obtained the King Count House Sales Dataset off Kaggle. While scrubbing the data I looked for categorical information, duplicates, nulls, and any abnormal symbols or outliers. During the exploration phase I took a deeper look at multicollinearity, categorical data, and z-scores. Finally I modeled the information using OLS Regression Analysis to help us understand "What makes a houses price increase?"
#
# >These are the results I found:
# 1. Increase the number of bedrooms and bathrooms in the home. From our data 5 bedrooms increases a homes price to about 500,000 dollars. Having 3 or bathrooms brings the price over 500,000 dollars as well.
# 2. Use high grade materials while building. On a scale of 1-12 for material quality an 8 or higher would set the house's sale price at over 500,000.
# 3. Purchase a home that is waterfront. On average, a home that is on water is 300,000 dollars more expensive.
# 4. Have at least 3 viewings before selling. According to our data, showing the house multiple times provides more competition from buyers. (If you have an offer you are happy with, there is no harm in closing after one viewing.)

# %% [markdown]
# # Introduction

# %% [markdown]
# Within this notebook I am taking a look at the King County House Sales Dataset with the goal of interpreting sale prices of homes. The purpose of this is to aid current homeowners in answering the question "What can I do to increase the value of my home?"
#
# The notebook follows the OSEMN framework where I obtained the data, scrubbed, explored, modeled, and then finally interpreted the results. In order to make the best recommendations to my clients I explored the data using the OLS regression analysis. After making the initial model, I went back over the data and looked for ways to improve the R^2 and ways to drop multicollinearity for the best results. Once I executed the above steps I performed a test train split to validate the results. These steps have been used to give the best recommendations to my client about increasing the sale price of their home.

# %% [markdown]
# # Tableau Price Visualizations

# %% [markdown]
# ### Price vs. Location

# %% [markdown]
# > By reading this tableau visualizations, we can see that more of the expensive households are in the northeast region of King County.

# %%
# %%html
# <div class='tableauPlaceholder' id='viz1598550555604' style='position: relative'><noscript><a href='#'><img alt=' ' src='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Pr&#47;Pricevs_Location&#47;Sheet1&#47;1_rss.png' style='border: none' /></a></noscript><object class='tableauViz'  style='display:none;'><param name='host_url' value='https%3A%2F%2Fpublic.tableau.com%2F' /> <param name='embed_code_version' value='3' /> <param name='site_root' value='' /><param name='name' value='Pricevs_Location&#47;Sheet1' /><param name='tabs' value='no' /><param name='toolbar' value='yes' /><param name='static_image' value='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Pr&#47;Pricevs_Location&#47;Sheet1&#47;1.png' /> <param name='animate_transition' value='yes' /><param name='display_static_image' value='yes' /><param name='display_spinner' value='yes' /><param name='display_overlay' value='yes' /><param name='display_count' value='yes' /><param name='language' value='en' /><param name='filter' value='publish=yes' /></object></div>                <script type='text/javascript'>                    var divElement = document.getElementById('viz1598550555604');                    var vizElement = divElement.getElementsByTagName('object')[0];                    vizElement.style.width='100%';vizElement.style.height=(divElement.offsetWidth*0.75)+'px';                    var scriptElement = document.createElement('script');                    scriptElement.src = 'https://public.tableau.com/javascripts/api/viz_v1.js';                    vizElement.parentNode.insertBefore(scriptElement, vizElement);                </script>
# Out:
# <div class='tableauPlaceholder' id='viz1598550555604' style='position: relative'><noscript><a href='#'><img alt=' ' src='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Pr&#47;Pricevs_Location&#47;Sheet1&#47;1_rss.png' style='border: none' /></a></noscript><object class='tableauViz'  style='display:none;'><param name='host_url' value='https%3A%2F%2Fpublic.tableau.com%2F' /> <param name='embed_code_version' value='3' /> <param name='site_root' value='' /><param name='name' value='Pricevs_Location&#47;Sheet1' /><param name='tabs' value='no' /><param name='toolbar' value='yes' /><param name='static_image' value='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Pr&#47;Pricevs_Location&#47;Sheet1&#47;1.png' /> <param name='animate_transition' value='yes' /><param name='display_static_image' value='yes' /><param name='display_spinner' value='yes' /><param name='display_overlay' value='yes' /><param name='display_count' value='yes' /><param name='language' value='en
# ...

# %% [markdown]
# ### Price vs. Zipcode

# %% [markdown]
# > Looking at price vs. zipcode we are able to see that it matches with the above tableau. The more expensive houses are in the north/northeast area of King County.

# %%
# %%html
# <div class='tableauPlaceholder' id='viz1598550849044' style='position: relative'><noscript><a href='#'><img alt=' ' src='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Pr&#47;Pricevs_Location&#47;Sheet2&#47;1_rss.png' style='border: none' /></a></noscript><object class='tableauViz'  style='display:none;'><param name='host_url' value='https%3A%2F%2Fpublic.tableau.com%2F' /> <param name='embed_code_version' value='3' /> <param name='path' value='views&#47;Pricevs_Location&#47;Sheet2?:language=en&amp;:embed=y&amp;:display_count=y&amp;publish=yes' /> <param name='toolbar' value='yes' /><param name='static_image' value='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Pr&#47;Pricevs_Location&#47;Sheet2&#47;1.png' /> <param name='animate_transition' value='yes' /><param name='display_static_image' value='yes' /><param name='display_spinner' value='yes' /><param name='display_overlay' value='yes' /><param name='display_count' value='yes' /><param name='language' value='en' /><param name='filter' value='publish=yes' /></object></div>                <script type='text/javascript'>                    var divElement = document.getElementById('viz1598550849044');                    var vizElement = divElement.getElementsByTagName('object')[0];                    vizElement.style.width='100%';vizElement.style.height=(divElement.offsetWidth*0.75)+'px';                    var scriptElement = document.createElement('script');                    scriptElement.src = 'https://public.tableau.com/javascripts/api/viz_v1.js';                    vizElement.parentNode.insertBefore(scriptElement, vizElement);                </script>
# Out:
# <div class='tableauPlaceholder' id='viz1598550849044' style='position: relative'><noscript><a href='#'><img alt=' ' src='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Pr&#47;Pricevs_Location&#47;Sheet2&#47;1_rss.png' style='border: none' /></a></noscript><object class='tableauViz'  style='display:none;'><param name='host_url' value='https%3A%2F%2Fpublic.tableau.com%2F' /> <param name='embed_code_version' value='3' /> <param name='path' value='views&#47;Pricevs_Location&#47;Sheet2?:language=en&amp;:embed=y&amp;:display_count=y&amp;publish=yes' /> <param name='toolbar' value='yes' /><param name='static_image' value='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Pr&#47;Pricevs_Location&#47;Sheet2&#47;1.png' /> <param name='animate_transition' value='yes' /><param name='display_static_image' value='yes' /><param name='display_spinner' value='yes' /><param name='display_overlay' value='yes' /><param name='display_count' value='yes' /><param name='language' va
# ...

# %% [markdown]
# ### Location vs. Yearbuilt

# %% [markdown]
# > I wanted to take a look at where the newer houses were being built in King County. Looking at the tableau below we can see that most new houses are going up northeast of the city as well. This leads me to believe that the new homes are selling for more.

# %%
# %%html
# <div class='tableauPlaceholder' id='viz1598550894188' style='position: relative'><noscript><a href='#'><img alt=' ' src='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Yr&#47;YrBuiltvs_Location&#47;Sheet3&#47;1_rss.png' style='border: none' /></a></noscript><object class='tableauViz'  style='display:none;'><param name='host_url' value='https%3A%2F%2Fpublic.tableau.com%2F' /> <param name='embed_code_version' value='3' /> <param name='site_root' value='' /><param name='name' value='YrBuiltvs_Location&#47;Sheet3' /><param name='tabs' value='no' /><param name='toolbar' value='yes' /><param name='static_image' value='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Yr&#47;YrBuiltvs_Location&#47;Sheet3&#47;1.png' /> <param name='animate_transition' value='yes' /><param name='display_static_image' value='yes' /><param name='display_spinner' value='yes' /><param name='display_overlay' value='yes' /><param name='display_count' value='yes' /><param name='language' value='en' /><param name='filter' value='publish=yes' /></object></div>                <script type='text/javascript'>                    var divElement = document.getElementById('viz1598550894188');                    var vizElement = divElement.getElementsByTagName('object')[0];                    vizElement.style.width='100%';vizElement.style.height=(divElement.offsetWidth*0.75)+'px';                    var scriptElement = document.createElement('script');                    scriptElement.src = 'https://public.tableau.com/javascripts/api/viz_v1.js';                    vizElement.parentNode.insertBefore(scriptElement, vizElement);                </script>
# Out:
# <div class='tableauPlaceholder' id='viz1598550894188' style='position: relative'><noscript><a href='#'><img alt=' ' src='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Yr&#47;YrBuiltvs_Location&#47;Sheet3&#47;1_rss.png' style='border: none' /></a></noscript><object class='tableauViz'  style='display:none;'><param name='host_url' value='https%3A%2F%2Fpublic.tableau.com%2F' /> <param name='embed_code_version' value='3' /> <param name='site_root' value='' /><param name='name' value='YrBuiltvs_Location&#47;Sheet3' /><param name='tabs' value='no' /><param name='toolbar' value='yes' /><param name='static_image' value='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Yr&#47;YrBuiltvs_Location&#47;Sheet3&#47;1.png' /> <param name='animate_transition' value='yes' /><param name='display_static_image' value='yes' /><param name='display_spinner' value='yes' /><param name='display_overlay' value='yes' /><param name='display_count' value='yes' /><param name='language' val
# ...

# %% [markdown]
# # Obtain Data

# %% [markdown]
# ### Import Data

# %%
#Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import statsmodels.api as sm
import statsmodels.formula.api as smf
# Out:
# /Users/laurenesser/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
#Import data using pandas
df = pd.read_csv("kc_house_data.csv")
#Set display to maximum rows
pd.set_option('display.max_columns', 0)
df.head()
# Out:
#            id        date     price  ...     long  sqft_living15  sqft_lot15
# 0  7129300520  10/13/2014  221900.0  ... -122.257           1340        5650
# 1  6414100192   12/9/2014  538000.0  ... -122.319           1690        7639
# 2  5631500400   2/25/2015  180000.0  ... -122.233           2720        8062
# 3  2487200875   12/9/2014  604000.0  ... -122.393           1360        5000
# 4  1954400510   2/18/2015  510000.0  ... -122.045           1800        7503
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Check for Duplicates

# %% [markdown]
# > Below I checked for duplicates in the dataframe using the id column:
#
# > **177 duplicates**
#
# >**Explanation**:
# >Reasoning for this could be if a specific house sold more than one time over the data collection period. I chose to drop the duplicates for the id column in order to represent each house only once. By using keep = first I chose to keep the first occurring id only and drop any after that.

# %%
#Check for duplicates
duplicates = df[df.duplicated(subset = 'id')]
print(len(duplicates))
duplicates.head()
# Out:
# 177
#              id        date      price  ...     long  sqft_living15  sqft_lot15
# 94   6021501535  12/23/2014   700000.0  ... -122.386           1570        4500
# 314  4139480200   12/9/2014  1400000.0  ... -122.102           3860       11244
# 325  7520000520   3/11/2015   240500.0  ... -122.352           1820        7460
# 346  3969300030  12/29/2014   239900.0  ... -122.240           1020        7138
# 372  2231500030   3/24/2015   530000.0  ... -122.341           1810        6929
#
# [5 rows x 21 columns]

# %%
#Drop duplicates using id column.
df.drop_duplicates(subset ="id", 
                     keep = 'first', inplace = True)

# %%
#Recheck for duplicates
duplicates = df[df.duplicated(subset = 'id')]
print(len(duplicates))
duplicates.head()
# Out:
# 0
# Empty DataFrame
# Columns: [id, date, price, bedrooms, bathrooms, sqft_living, sqft_lot, floors, waterfront, view, condition, grade, sqft_above, sqft_basement, yr_built, yr_renovated, zipcode, lat, long, sqft_living15, sqft_lot15]
# Index: []

# %% [markdown]
# ### Inspect Columns in the DataFrame

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21420 entries, 0 to 21596
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21420 non-null  int64
#  1   date           21420 non-null  object
#  2   price          21420 non-null  float64
#  3   bedrooms       21420 non-null  int64
#  4   bathrooms      21420 non-null  float64
#  5   sqft_living    21420 non-null  int64
#  6   sqft_lot       21420 non-null  int64
#  7   floors         21420 non-null  float64
#  8   waterfront     19067 non-null  float64
#  9   view           21357 non-null  float64
#  10  condition      21420 non-null  int64
#  11  grade          21420 non-null  int64
#  12  sqft_above     21420 non-null  int64
#  13  sqft_basement  21420 non-null  object
#  14  yr_built       21420 non-null  int64
#  15  yr_renovated   17616 non-null  float64
#  16  zipcode        21420 non-null  int64
# ...

# %%
#check len/val
df.id.sort_values()
# Out:
# 2494        1000102
# 6729        1200019
# 8404        1200021
# 8800        2800031
# 3553        3600057
#             ...
# 16723    9842300095
# 3257     9842300485
# 7614     9842300540
# 20963    9895000040
# 15937    9900000190
# Name: id, Length: 21420, dtype: int64

# %%
#drop id since it is no longer needed
df.drop(['id'], axis=1, inplace=True)

# %% [markdown]
# > **Observations**:
# > - *D-Types*:
#     - float64 = 8
#     - int64 = 10
#     - object = 2 (Need to switch sqft_basement over to float)
# - *Missing Data*:
#     - waterfront
#     - view
#     - yr_renovated

# %% [markdown]
# > **Summary**: In the obtain section I uploaded the data, checked for duplicates, inspected information about the dataset and dropped the id column.

# %% [markdown]
# # Scrub

# %% [markdown]
# ### Check for labeled categorical columns

# %%
#Create categorical variable
cat_cols = df.select_dtypes('object')
cat_cols
# Out:
#              date sqft_basement
# 0      10/13/2014           0.0
# 1       12/9/2014         400.0
# 2       2/25/2015           0.0
# 3       12/9/2014         910.0
# 4       2/18/2015           0.0
# ...           ...           ...
# 21592   5/21/2014           0.0
# 21593   2/23/2015           0.0
# 21594   6/23/2014           0.0
# 21595   1/16/2015           0.0
# 21596  10/15/2014           0.0
#
# [21420 rows x 2 columns]

# %%
#while at it create numerical columns list
num_cols = list(df.select_dtypes('number').columns)
num_cols
# Out:
# ['price',
#  'bedrooms',
#  'bathrooms',
#  'sqft_living',
#  'sqft_lot',
#  'floors',
#  'waterfront',
#  'view',
#  'condition',
#  'grade',
#  'sqft_above',
#  'yr_built',
#  'yr_renovated',
#  'zipcode',
#  'lat',
#  'long',
#  'sqft_living15',
#  'sqft_lot15']

# %% [markdown]
# >**Explanation**:
# > Above shows that there are only two columns labeled as an object or categorical column: **date and sqft_basement**. Since sqft_basement is *numerical* I am going to first check and take care of unique values then convert it to a float below.

# %%
#Look at val_counts for sqft_basement
df.sqft_basement.value_counts(dropna = False, normalize=True)
# Out:
# 0.0       0.593697
# ?         0.021102
# 600.0     0.010084
# 500.0     0.009617
# 700.0     0.009570
#             ...
# 143.0     0.000047
# 2570.0    0.000047
# 3480.0    0.000047
# 2130.0    0.000047
# 374.0     0.000047
# Name: sqft_basement, Length: 304, dtype: float64

# %%
#replace ? with 0.0
df.sqft_basement = df.sqft_basement.replace('?', '0.0')

# %% [markdown]
# > **Explanation**:
# Here I am assuming that a
# **?** means there is no basement present therefore I switched all question marks over to *0.0* in the data.

# %%
#Save and convert to float
df.sqft_basement = df.sqft_basement.astype('float')

# %%
#Recheck val_counts
df.sqft_basement.value_counts(dropna = False, normalize=True)
# Out:
# 0.0       0.614799
# 600.0     0.010084
# 500.0     0.009617
# 700.0     0.009570
# 800.0     0.009384
#             ...
# 915.0     0.000047
# 295.0     0.000047
# 1281.0    0.000047
# 2130.0    0.000047
# 906.0     0.000047
# Name: sqft_basement, Length: 303, dtype: float64

# %% [markdown]
# ### Checking Null Values

# %% [markdown]
# > **Explanation**: Installed missingno, this allows for visualization of the null values before getting started. I can already see that waterfront and yr_renovated will have a high number of nulls.

# %%
import missingno as ms
ms.matrix(df)
# Out:
# <AxesSubplot:>

# %% [markdown]
# > **Explanation**: Below I looked to see if there are any rows with over two nulls. Since more information is missing I chose to drop those rows.

# %%
#num. of rows missing amnt of data
df.isna().sum(axis=1).value_counts()
# Out:
# 0    15644
# 1     5334
# 2      440
# 3        2
# dtype: int64

# %%
#Keep rows w/ less than 3 Null
keep_rows = df.isna().sum(axis=1) < 3

# %%
df = df[keep_rows]

# %%
df.isna().sum()
# Out:
# date                0
# price               0
# bedrooms            0
# bathrooms           0
# sqft_living         0
# sqft_lot            0
# floors              0
# waterfront       2351
# view               61
# condition           0
# grade               0
# sqft_above          0
# sqft_basement       0
# yr_built            0
# yr_renovated     3802
# zipcode             0
# lat                 0
# long                0
# sqft_living15       0
# sqft_lot15          0
# dtype: int64

# %% [markdown]
# > **Observations**:
# - Three columns with Null values: *waterfront, view, and yr_renovated*. I will go through each of the columns below.

# %% [markdown]
# ### Waterfront

# %%
#Check majority
df.waterfront.value_counts()
# Out:
# 0.0    18921
# 1.0      146
# Name: waterfront, dtype: int64

# %%
#Fill NaN with 0.0, assume no waterfront
df['waterfront'] = df['waterfront'].fillna(0.0)

# %%
#NaN check
df.isna().sum()
# Out:
# date                0
# price               0
# bedrooms            0
# bathrooms           0
# sqft_living         0
# sqft_lot            0
# floors              0
# waterfront          0
# view               61
# condition           0
# grade               0
# sqft_above          0
# sqft_basement       0
# yr_built            0
# yr_renovated     3802
# zipcode             0
# lat                 0
# long                0
# sqft_living15       0
# sqft_lot15          0
# dtype: int64

# %% [markdown]
# ### View

# %%
#less than 5% consider dropping
df.view.value_counts(dropna = False, normalize = True)
# Out:
# 0.0    0.898917
# 2.0    0.044635
# 3.0    0.023578
# 1.0    0.015361
# 4.0    0.014661
# NaN    0.002848
# Name: view, dtype: float64

# %%
# .2% deciding to drop NaN views
df.dropna(subset = ['view'], inplace=True)

# %%
df.view.isna().sum()
# Out:
# 0

# %% [markdown]
# ### Yr_renovated

# %%
#Assume NaN = no reno & replace with 0
df['yr_renovated'] = df['yr_renovated'].fillna(0.0)

# %%
#Check NaN
df.yr_renovated.isna().sum()
# Out:
# 0

# %% [markdown]
# ### Check for abnormal symbols or characters

# %%
#Check for abnormal symbols etc.
for col in df.columns:
    try: 
        print(col, '\n', df[col].value_counts(normalize=True).head(), '\n\n')
    except:
        (print(col, df[col].value_counts()))
# Out:
# date
#  6/23/2014    0.006649
# 6/26/2014    0.006134
# 6/25/2014    0.006134
# 7/8/2014     0.005947
# 4/27/2015    0.005806
# Name: date, dtype: float64
#
#
# price
#  350000.0    0.008007
# 450000.0    0.007960
# 550000.0    0.007304
# 500000.0    0.007070
# 425000.0    0.007023
# Name: price, dtype: float64
#
#
# bedrooms
#  3    0.454090
# 4    0.319895
# 2    0.127827
# 5    0.074027
# 6    0.012314
# Name: bedrooms, dtype: float64
#
#
# bathrooms
#  2.50    0.249988
# 1.00    0.177178
# 1.75    0.140797
# 2.25    0.094629
# 2.00    0.089385
# Name: bathrooms, dtype: float64
#
#
# sqft_living
#  1300    0.006368
# 1440    0.006227
# 1400    0.006134
# 1800    0.005993
# 1660    0.005993
# Name: sqft_living, dtype: float64
#
#
# sqft_lot
#  5000    0.016575
# 6000    0.013391
# 4000    0.011659
# 7200    0.010207
# 7500    0.005478
# Name: sqft_lot, dtype: float64
#
#
# floors
#  1.0    0.492672
# 2.0    0.382966
# 1.5    0.088074
# 3.0    0.028515
# 2.5    0.007445
# ...

# %% [markdown]
# > **Summary**: In the scrub section I took care of null values, converted an object column to float, and checked for abnormal characters or symbols.

# %% [markdown]
# # Explore

# %% [markdown]
# ### Objective: Answer the following three questions:

# %% [markdown]
# >1. Is there multicollinearity among features? *Answer in 6.0.10*
# 2. Do outliers impact the overall model? *Answer in 7.0.2 Using IQR to Check for  Outliers*
# 3. Does log transformation improve the overall model? *Answer in 7.0.6 Log Transformation*

# %% [markdown]
# ### Exploring the dataset

# %%
#color palette for visualizations
sns.palplot(sns.color_palette("BuGn_r"))

# %%
#set palette
sns.set_palette("BuGn_r")

# %%
#descriptive statistics
df.describe()
# Out:
#               price      bedrooms  ...  sqft_living15     sqft_lot15
# count  2.135700e+04  21357.000000  ...   21357.000000   21357.000000
# mean   5.404997e+05      3.373788  ...    1988.066255   12768.505876
# std    3.666157e+05      0.925514  ...     685.428458   27326.770308
# min    7.800000e+04      1.000000  ...     399.000000     651.000000
# 25%    3.225000e+05      3.000000  ...    1490.000000    5100.000000
# 50%    4.500000e+05      3.000000  ...    1840.000000    7620.000000
# 75%    6.450000e+05      4.000000  ...    2370.000000   10087.000000
# max    7.700000e+06     33.000000  ...    6210.000000  871200.000000
#
# [8 rows x 19 columns]

# %% [markdown]
# >**Observations**:
# - Noticeable outliers: price, bedroom, bathroom, sqft_living, sqft_lot, sqft_above, sqft_basement, sqft_living15, sqft_lot15
# - Most houses have 3 bedrooms and 2 bath.
# - Mean condition is 3.41 meaning average condition. Grade is 7.6 out of 10 meaning most houses are build with good materials.
# - Average year built is 1971
# - High std: price, sqft_living, sqft_loft, sqft_above, sqft_basement, yr_built (more categorical), yr_renovated (more categorical), zipcode (categorical), sqft_living15, sqft_lot15

# %%
#examine target
target = 'price'
sns.distplot(df[target]).set_title('Distplot of Price');

# %% [markdown]
# > **Observation**: Displot looks like a slight left skew.

# %%
sns.boxplot(y= df[target]).set_title("Boxplot of Price");

# %% [markdown]
# > **Observation**: Boxplot shows outliers on the high price end.

# %%
#Inspecting target vs. independent variables
sns.jointplot(data=df, x = 'bedrooms', y=target,  kind = 'reg')

# %% [markdown]
# > **Observations**:
# > - Bedrooms have a linear relationship with price.
# > - One major outlier to take care of.

# %% [markdown]
# > **Explanation**: Below I set up a joint plot to compare the dependent and independent variables. The coding and use of interact came from a in class lesson to make sorting through graphs of columns easier.

# %%
joint = sns.jointplot(data=df, x = 'bedrooms', y=target,  kind = 'reg')
fig = joint.fig
ax = fig.get_axes()

# %%
def joint_graphs(df, col, target = 'price'):
    '''insert dataframe, column, and target in order to create a
    jointplot comparing the col to the target'''
    sns.set(rc={'axes.labelsize': 14})
    sns.set_palette("BuGn_r")        
    joint = sns.jointplot(data = df, x = col, y=target,
                          kind='reg', height = 7)
                          
    plt.suptitle(f" Comparing {col} and {target}", fontsize = 14)
    return joint

# %%
#test the function
joint_graphs(df, 'sqft_lot')

# %%
from ipywidgets import interact

# %%
@interact 
def show_plot(col=num_cols):
    joint_graphs(df, col)
# Out:
# interactive(children=(Dropdown(description='col', options=('price', 'bedrooms', 'bathrooms', 'sqft_living', 's…

# %% [markdown]
# ### Ordinal Categorical Data

# %% [markdown]
# > **Explanation**: Below I decided to make *zipcode* and *condition* categorical data. Using get_dummies I one-hot encoded those columns.

# %%
#Use Dummy encoding/One-Hot Encoding
df_ohe = pd.get_dummies(df, columns=['zipcode', 'condition'], drop_first=True)

# %%
#visualize
df_ohe.head()
# Out:
#          date     price  bedrooms  ...  condition_3  condition_4  condition_5
# 0  10/13/2014  221900.0         3  ...            1            0            0
# 1   12/9/2014  538000.0         3  ...            1            0            0
# 2   2/25/2015  180000.0         2  ...            1            0            0
# 3   12/9/2014  604000.0         4  ...            0            0            1
# 4   2/18/2015  510000.0         3  ...            1            0            0
#
# [5 rows x 91 columns]

# %% [markdown]
# ### First OLS Regression Analysis

# %%
#Drop price since it is target column & date is not being used
features = '+'.join(df_ohe.drop(columns=['price', 'date']).columns)
features
# Out:
# 'bedrooms+bathrooms+sqft_living+sqft_lot+floors+waterfront+view+grade+sqft_above+sqft_basement+yr_built+yr_renovated+lat+long+sqft_living15+sqft_lot15+zipcode_98002+zipcode_98003+zipcode_98004+zipcode_98005+zipcode_98006+zipcode_98007+zipcode_98008+zipcode_98010+zipcode_98011+zipcode_98014+zipcode_98019+zipcode_98022+zipcode_98023+zipcode_98024+zipcode_98027+zipcode_98028+zipcode_98029+zipcode_98030+zipcode_98031+zipcode_98032+zipcode_98033+zipcode_98034+zipcode_98038+zipcode_98039+zipcode_98040+zipcode_98042+zipcode_98045+zipcode_98052+zipcode_98053+zipcode_98055+zipcode_98056+zipcode_98058+zipcode_98059+zipcode_98065+zipcode_98070+zipcode_98072+zipcode_98074+zipcode_98075+zipcode_98077+zipcode_98092+zipcode_98102+zipcode_98103+zipcode_98105+zipcode_98106+zipcode_98107+zipcode_98108+zipcode_98109+zipcode_98112+zipcode_98115+zipcode_98116+zipcode_98117+zipcode_98118+zipcode_98119+zipcode_98122+zipcode_98125+zipcode_98126+zipcode_98133+zipcode_98136+zipcode_98144+zipcode_98146+zipcode
# ...

# %%
formula = target + '~' + features
model = smf.ols(formula, df_ohe).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.809
# Model:                            OLS   Adj. R-squared:                  0.808
# Method:                 Least Squares   F-statistic:                     1012.
# Date:                Tue, 08 Sep 2020   Prob (F-statistic):               0.00
# Time:                        18:52:26   Log-Likelihood:            -2.8625e+05
# No. Observations:               21357   AIC:                         5.727e+05
# Df Residuals:                   21267   BIC:                         5.734e+05
# Df Model:                          89
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %%
#Create function to make it quicker to graph visualizations.
def create_visuals(y_true, model):
    '''Plot OLS diagnostic visuals'''
    fig, axes = plt.subplots(ncols=2, figsize=(10,6))
    
    sm.graphics.qqplot(model.resid, fit=True, 
                       line= '45', color = 'g', ax=axes[0])
   
    ax = axes[1]
    ax = sns.scatterplot(y_true, model.resid, color = 'g')
    ax.axhline(linewidth=2, color='r')
    plt.suptitle(f" QQplot and Homoskedasticity Check", fontsize = 14)
    plt.tight_layout()

# %%
#test function
create_visuals(df_ohe[target], model)

# %% [markdown]
# >**Observations**:
# - Higher R-squared of .809. (Original R-squared was .700. Went back and decided to scrub data better.)
# - Problem P-value rows
# - Multicolinearity of 2.84e+08
# - QQPlot needs work

# %% [markdown]
# ### Dealing with P-Values

# %%
#sort model pvals in ascending order. Round 3 digits.
p_val = round(model.pvalues.sort_values(ascending=True), 3)

# %%
p_val
# Out:
# waterfront       0.000
# zipcode_98039    0.000
# view             0.000
# grade            0.000
# zipcode_98004    0.000
#                  ...
# zipcode_98031    0.612
# zipcode_98032    0.614
# zipcode_98188    0.642
# zipcode_98030    0.798
# zipcode_98178    0.898
# Length: 90, dtype: float64

# %%
#list of pval over .05
p_removal = list(p_val[p_val > .05].index)

# %%
p_removal
# Out:
# ['sqft_basement',
#  'zipcode_98003',
#  'zipcode_98155',
#  'zipcode_98077',
#  'zipcode_98092',
#  'zipcode_98198',
#  'zipcode_98055',
#  'zipcode_98019',
#  'zipcode_98011',
#  'zipcode_98148',
#  'zipcode_98028',
#  'zipcode_98042',
#  'zipcode_98058',
#  'zipcode_98166',
#  'zipcode_98031',
#  'zipcode_98032',
#  'zipcode_98188',
#  'zipcode_98030',
#  'zipcode_98178']

# %% [markdown]
# > **Explanation**: Above I am checking to see if 'Intercept' is listed in the p_removal list. It is not so I can proceed.

# %%
# % of overall data to drop
len(p_removal)/len(df_ohe.columns)
# Out:
# 0.2087912087912088

# %%
#remove high pvals from data
for col in p_removal:
    if col in df_ohe.columns:
        df_ohe.drop(columns=col, inplace = True)

# %% [markdown]
# ### Second OSL Regression Analysis

# %% [markdown]
# > In between the first and second OLS model I removed p-values higher than .05.

# %%
features = '+'.join(df_ohe.drop(columns=['price', 'date']).columns)

# %%
formula = target + '~' + features
model = smf.ols(formula, df_ohe).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.809
# Model:                            OLS   Adj. R-squared:                  0.808
# Method:                 Least Squares   F-statistic:                     1286.
# Date:                Tue, 08 Sep 2020   Prob (F-statistic):               0.00
# Time:                        18:52:28   Log-Likelihood:            -2.8627e+05
# No. Observations:               21357   AIC:                         5.727e+05
# Df Residuals:                   21286   BIC:                         5.732e+05
# Df Model:                          70
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %% [markdown]
# >**Observations**:
# - R-squared did not change .809
# - P-values taken care of
# - Multicolinearity dropped to 1.33e+.08

# %% [markdown]
# ### SCRUB: Checking for multicollinearity

# %%
df_ohe.shape
# Out:
# (21357, 72)

# %%
#select columns
df_ohe.iloc[:, 2:72]
# Out:
#        bedrooms  bathrooms  sqft_living  ...  condition_3  condition_4  condition_5
# 0             3       1.00         1180  ...            1            0            0
# 1             3       2.25         2570  ...            1            0            0
# 2             2       1.00          770  ...            1            0            0
# 3             4       3.00         1960  ...            0            0            1
# 4             3       2.00         1680  ...            1            0            0
# ...         ...        ...          ...  ...          ...          ...          ...
# 21592         3       2.50         1530  ...            1            0            0
# 21593         4       2.50         2310  ...            1            0            0
# 21594         2       0.75         1020  ...            1            0            0
# 21595         3       2.50         1600  ...            1            0            0
# ...

# %% [markdown]
# > **Explanation**: Take a copy of the data without the target variable of "price". Also dropped "date" because keeping it in won't lead to meaningful results.

# %%
data_pred = df_ohe.iloc[:, 2:72]
data_pred.head()
# Out:
#    bedrooms  bathrooms  sqft_living  ...  condition_3  condition_4  condition_5
# 0         3       1.00         1180  ...            1            0            0
# 1         3       2.25         2570  ...            1            0            0
# 2         2       1.00          770  ...            1            0            0
# 3         4       3.00         1960  ...            0            0            1
# 4         3       2.00         1680  ...            1            0            0
#
# [5 rows x 70 columns]

# %% [markdown]
# > **Explanation**: Created a correlation matrix. Negative numbers represent negative linear relationships whereas positive numbers represent a positive linear relationship.

# %%
data_pred.corr()
# Out:
#                bedrooms  bathrooms  ...  condition_4  condition_5
# bedrooms       1.000000   0.515245  ...    -0.009628     0.026836
# bathrooms      0.515245   1.000000  ...    -0.168274    -0.036391
# sqft_living    0.578790   0.755037  ...    -0.084950    -0.019755
# sqft_lot       0.032756   0.088328  ...     0.013178    -0.014100
# floors         0.177177   0.501502  ...    -0.259715    -0.121381
# ...                 ...        ...  ...          ...          ...
# zipcode_98199 -0.021716   0.008331  ...    -0.005234     0.023321
# condition_2   -0.049304  -0.074046  ...    -0.052264    -0.025570
# condition_3    0.005079   0.192481  ...    -0.812918    -0.397721
# condition_4   -0.009628  -0.168274  ...     1.000000    -0.174848
# condition_5    0.026836  -0.036391  ...    -0.174848     1.000000
#
# [70 rows x 70 columns]

# %% [markdown]
# > **Explanation**: Took a look to see how many highly correlated variables are present. I set the cut-off as .75. Where it states true leads me to believe there is high correlation.

# %%
abs(data_pred.corr()) > 0.75
# Out:
#                bedrooms  bathrooms  ...  condition_4  condition_5
# bedrooms           True      False  ...        False        False
# bathrooms         False       True  ...        False        False
# sqft_living       False       True  ...        False        False
# sqft_lot          False      False  ...        False        False
# floors            False      False  ...        False        False
# ...                 ...        ...  ...          ...          ...
# zipcode_98199     False      False  ...        False        False
# condition_2       False      False  ...        False        False
# condition_3       False      False  ...         True        False
# condition_4       False      False  ...         True        False
# condition_5       False      False  ...        False         True
#
# [70 rows x 70 columns]

# %% [markdown]
# > **Explanation**: Created a heatmap to show the correlation matrix as a visualization. The lighter the number the higher the correlation.

# %%
corr = data_pred.corr().abs()
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True
with sns.axes_style("white"):
    f, ax = plt.subplots(figsize=(28, 20))
    ax = sns.heatmap(corr, mask=mask, annot = True, linewidths=1, 
                     square=True, cbar_kws={'shrink':0.6}, 
                     cmap="BuGn_r")

# %% [markdown]
# > **Explanation**: Below I calculated multicollinearity using the module method and what was shown in class. Based on results and discussing with instructor I originally chose to go strictly with vif. Later I came back to look at the data and realized that sqft_living had such a large issue with other columns that dropping it here could allow less columns to be dropped in the vif later on.

# %%
# save absolute value of correlation matrix as a data frame
# converts all values to absolute value
# stacks the row:column pairs into a multindex
# reset the index to set the multindex to seperate columns
# sort values. 0 is the column automatically generated by the stacking

df1 = data_pred.corr().abs().stack().reset_index().sort_values(0, ascending=False)

#zip new columns into pairs
df1['pairs'] = list(zip(df1.level_0, df1.level_1))

#set index to pairs
df1.set_index(['pairs'], inplace=True)

#drop level columns
df1.drop(columns=['level_1', 'level_0'], inplace=True)

#rename from 0 to cc
df1.columns = ['cc']
df1.drop_duplicates(inplace=True)

# %%
df1[(df1.cc>.75) & (df1.cc< 1)]
# Out:
#                                     cc
# pairs
# (sqft_above, sqft_living)     0.876640
# (condition_4, condition_3)    0.812918
# (sqft_living, grade)          0.762092
# (grade, sqft_above)           0.756126
# (sqft_living, sqft_living15)  0.755991
# (bathrooms, sqft_living)      0.755037

# %% [markdown]
# > **Observation from Module Method**:
# - sqft_living has high correlation with sqft_above, grade, sqft_living15, and bathrooms.
# - Condition 3 and 4
# - Grade with sqft_above
#
#
#
# >- Since sqft_living has a high correlation with multiple columns I am choosing to drop sqft_living in hopes that less columns will be dropped when I run my vif analysis.

# %%
#drop sqft_living
df_ohe = df_ohe.drop(columns = 'sqft_living')

# %% [markdown]
# ### Testing with VIF

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
df_ohe = df_ohe.drop('date', axis=1)

# %%
#drop target column
X = df_ohe.drop('price', axis=1)
X = sm.add_constant(X)
X.shape
# Out:
# (21357, 70)

# %%
vif = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]

# %%
vif_results = pd.Series(dict(zip(X.columns, vif)))
vif_results
# Out:
# const            6.913627e+06
# bedrooms         1.570949e+00
# bathrooms        2.850876e+00
# sqft_lot         2.108315e+00
# floors           2.197133e+00
#                      ...
# zipcode_98199    1.352396e+00
# condition_2      6.770580e+00
# condition_3      1.761550e+02
# condition_4      1.500296e+02
# condition_5      5.680925e+01
# Length: 70, dtype: float64

# %%
#drop any vif over the accepted value of 6
threshold = 6
bad_vif = list(vif_results[vif_results>threshold].index)
if 'const' in bad_vif:
    bad_vif.remove('const') 
bad_vif
# Out:
# ['long', 'condition_2', 'condition_3', 'condition_4', 'condition_5']

# %%
for col in bad_vif:
    if col in df_ohe.columns:
        df_ohe.drop(columns=col, inplace = True)

# %% [markdown]
# >**Explanation**:
# I dropped longitude and condition 2-5 due to multicollinearity. This is less columns than I originally dropped which shows that removing sqft_living above helped save columns from being dropped.

# %% [markdown]
# ### Third OLS Regression Analysis

# %% [markdown]
# > Between the second and third OLS model I took care of multicollinearity using heatmaps and vif.

# %%
features = '+'.join(df_ohe.drop(columns= 'price').columns)
features
# Out:
# 'bedrooms+bathrooms+sqft_lot+floors+waterfront+view+grade+sqft_above+yr_built+yr_renovated+lat+sqft_living15+sqft_lot15+zipcode_98002+zipcode_98004+zipcode_98005+zipcode_98006+zipcode_98007+zipcode_98008+zipcode_98010+zipcode_98014+zipcode_98022+zipcode_98023+zipcode_98024+zipcode_98027+zipcode_98029+zipcode_98033+zipcode_98034+zipcode_98038+zipcode_98039+zipcode_98040+zipcode_98045+zipcode_98052+zipcode_98053+zipcode_98056+zipcode_98059+zipcode_98065+zipcode_98070+zipcode_98072+zipcode_98074+zipcode_98075+zipcode_98102+zipcode_98103+zipcode_98105+zipcode_98106+zipcode_98107+zipcode_98108+zipcode_98109+zipcode_98112+zipcode_98115+zipcode_98116+zipcode_98117+zipcode_98118+zipcode_98119+zipcode_98122+zipcode_98125+zipcode_98126+zipcode_98133+zipcode_98136+zipcode_98144+zipcode_98146+zipcode_98168+zipcode_98177+zipcode_98199'

# %%
formula = target + '~' + features
model = smf.ols(formula, df_ohe).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.794
# Model:                            OLS   Adj. R-squared:                  0.794
# Method:                 Least Squares   F-statistic:                     1285.
# Date:                Tue, 08 Sep 2020   Prob (F-statistic):               0.00
# Time:                        18:53:25   Log-Likelihood:            -2.8705e+05
# No. Observations:               21357   AIC:                         5.742e+05
# Df Residuals:                   21292   BIC:                         5.747e+05
# Df Model:                          64
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %% [markdown]
# > **Observations**:
# - R-squared dropped to .794
# - P-values sqft_lot15 over, zipcode_98014,98022, 98070
# - Multicolinearity dropped to 2.99e+07

# %%
create_visuals(df_ohe[target], model)

# %% [markdown]
# ### Question One Answer:
# **Question**: Is there multicollinearity among features?
#
# >**Answer**: We can see that there is multicollinearity among features in the data set. Using a combination of the correlation method and the vif method we were able to see that many columns had an issule with multicollinearity. By dropping these columns the multicollinearity dropped from 2.84e+08 to 2.99e+07.

# %%
#Create function for p-values for easier removal
def p_val_removal(df, model):
    p_val = round(model.pvalues.sort_values(ascending=True), 3)
    p_removal = list(p_val[p_val > .05].index)
    len(p_removal)/len(df.columns)
    for col in p_removal:
        if col in df.columns:
            df.drop(columns=col, inplace = True)

# %%
p_val_removal(df_ohe, model)

# %%
df_ohe.head()
# Out:
#       price  bedrooms  bathrooms  ...  zipcode_98168  zipcode_98177  zipcode_98199
# 0  221900.0         3       1.00  ...              0              0              0
# 1  538000.0         3       2.25  ...              0              0              0
# 2  180000.0         2       1.00  ...              0              0              0
# 3  604000.0         4       3.00  ...              0              0              0
# 4  510000.0         3       2.00  ...              0              0              0
#
# [5 rows x 62 columns]

# %% [markdown]
# ### Fourth OLS Regression Analysis

# %% [markdown]
# > Between the third and fourth OLS model I created a function to take care of p-values greater than .05

# %%
#Second time removing pvals
features = '+'.join(df_ohe.drop(columns='price').columns)

# %%
formula = target + '~' + features
model = smf.ols(formula, df_ohe).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.794
# Model:                            OLS   Adj. R-squared:                  0.794
# Method:                 Least Squares   F-statistic:                     1348.
# Date:                Tue, 08 Sep 2020   Prob (F-statistic):               0.00
# Time:                        18:53:28   Log-Likelihood:            -2.8705e+05
# No. Observations:               21357   AIC:                         5.742e+05
# Df Residuals:                   21295   BIC:                         5.747e+05
# Df Model:                          61
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %% [markdown]
# > **Observations**:
# - R-squared still .794
# - P-values  fixed
# - Multicolinearity dropped to 2.56e+07

# %%
create_visuals(df_ohe[target], model)

# %% [markdown]
# ### SCRUB: Checking for outliers

# %%
df_ohe.hist(figsize=(12,12));

# %% [markdown]
# ### Using Z-score

# %%
import scipy.stats as stats

# %%
from scipy.stats import zscore
#convert to z-score
df_ohe_z = df_ohe.apply(zscore)

# %%
#check absolute
df_ohe_z.abs()
# Out:
#           price  bedrooms  ...  zipcode_98177  zipcode_98199
# 0      0.869050  0.403881  ...       0.109491       0.122352
# 1      0.006819  0.403881  ...       0.109491       0.122352
# 2      0.983341  1.484386  ...       0.109491       0.122352
# 3      0.173211  0.676625  ...       0.109491       0.122352
# 4      0.083195  0.403881  ...       0.109491       0.122352
# ...         ...       ...  ...            ...            ...
# 21592  0.492352  0.403881  ...       0.109491       0.122352
# 21593  0.383243  0.676625  ...       0.109491       0.122352
# 21594  0.377512  1.484386  ...       0.109491       0.122352
# 21595  0.383243  0.403881  ...       0.109491       0.122352
# 21596  0.587822  1.484386  ...       0.109491       0.122352
#
# [21357 rows x 62 columns]

# %%
#make a list of outliers
zFP = np.abs(stats.zscore(df_ohe))
print(zFP)
zFP.shape
# Out:
# [[0.86904954 0.40388059 1.45554871 ... 0.1116602  0.10949086 0.1223522 ]
#  [0.00681853 0.40388059 0.17138532 ... 0.1116602  0.10949086 0.1223522 ]
#  [0.98334084 1.48438639 1.45554871 ... 0.1116602  0.10949086 0.1223522 ]
#  ...
#  [0.3775124  1.48438639 1.78093552 ... 0.1116602  0.10949086 0.1223522 ]
#  [0.38324333 0.40388059 0.49677212 ... 0.1116602  0.10949086 0.1223522 ]
#  [0.58782203 1.48438639 1.78093552 ... 0.1116602  0.10949086 0.1223522 ]]
# (21357, 62)

# %%
#save new list with z-score < 3
df_ohe_out = df_ohe[(zFP<3).all(axis=1)]
df_ohe_out
# Out:
#           price  bedrooms  ...  zipcode_98177  zipcode_98199
# 0      221900.0         3  ...              0              0
# 2      180000.0         2  ...              0              0
# 6      257500.0         3  ...              0              0
# 12     310000.0         3  ...              0              0
# 16     395000.0         3  ...              0              0
# ...         ...       ...  ...            ...            ...
# 21549  341780.0         4  ...              0              0
# 21569  270000.0         3  ...              0              0
# 21575  572000.0         4  ...              0              0
# 21578  350000.0         4  ...              0              0
# 21582  541800.0         4  ...              0              0
#
# [4925 rows x 62 columns]

# %% [markdown]
# > **Explanation**: Using z-score to remove outliers made our dataset much smaller. Lets look at IQR to see if there is a difference.

# %% [markdown]
# ### Using IQR for check for outliers

# %%
#identify the diff quartiles
Q1 = df_ohe['price'].quantile(0.25)
Q3 = df_ohe['price'].quantile(0.75)
IQR = Q3-Q1
print(IQR)
# Out:
# 322500.0

# %%
Lower_Whisker = Q1-1.5*IQR
Upper_Whisker = Q3+1.5*IQR
print(Lower_Whisker, Upper_Whisker)
# Out:
# -161250.0 1128750.0

# %%
#Drop price outliers and save over dataframe
test = df_ohe[~((df_ohe['price'] < (Q1 - 1.5 * IQR)) |(df_ohe['price'] > (Q3 + 1.5 * IQR)))]
print(test.shape)
# Out:
# (20211, 62)

# %%
#original rows
df_ohe.shape
# Out:
# (21357, 62)

# %%
#new num of rows
test.shape
# Out:
# (20211, 62)

# %%
#original price boxplot
sns.boxplot(df_ohe['price']).set_title("With Outliers Price");

# %%
#new boxplot
sns.boxplot(test['price']).set_title("Without Outliers Price");

# %% [markdown]
# > **Explanation**: By looking at the above boxplots we can see that the outliers in the target column of price have been taken care of.

# %%
#orig max for price
df_ohe.describe()
# Out:
#               price      bedrooms  ...  zipcode_98177  zipcode_98199
# count  2.135700e+04  21357.000000  ...   21357.000000   21357.000000
# mean   5.404997e+05      3.373788  ...       0.011846       0.014749
# std    3.666157e+05      0.925514  ...       0.108196       0.120550
# min    7.800000e+04      1.000000  ...       0.000000       0.000000
# 25%    3.225000e+05      3.000000  ...       0.000000       0.000000
# 50%    4.500000e+05      3.000000  ...       0.000000       0.000000
# 75%    6.450000e+05      4.000000  ...       0.000000       0.000000
# max    7.700000e+06     33.000000  ...       1.000000       1.000000
#
# [8 rows x 62 columns]

# %%
#new max for price
test.describe()
# Out:
#               price      bedrooms  ...  zipcode_98177  zipcode_98199
# count  2.021100e+04  20211.000000  ...   20211.000000   20211.000000
# mean   4.769666e+05      3.331503  ...       0.011330       0.013409
# std    2.079344e+05      0.907414  ...       0.105843       0.115019
# min    7.800000e+04      1.000000  ...       0.000000       0.000000
# 25%    3.150000e+05      3.000000  ...       0.000000       0.000000
# 50%    4.375000e+05      3.000000  ...       0.000000       0.000000
# 75%    6.000000e+05      4.000000  ...       0.000000       0.000000
# max    1.120000e+06     33.000000  ...       1.000000       1.000000
#
# [8 rows x 62 columns]

# %% [markdown]
# > **Explanation**: We can see see that price's maximum number decreased proving the removal of outliers.

# %%
#Create IQR function for easier removal
def IQR_removal(col, test):
    Q1 = test[col].quantile(0.25)
    Q3 = test[col].quantile(0.75)
    IQR = Q3-Q1
    print(IQR)

    num_rows = len(test)
    test = test[~((test[col] < (Q1 - 1.5 * IQR)) |(test[col] > (Q3 + 1.5 * IQR)))]
    num_outliers = num_rows - len(test)
    print(test.shape)
    print(f"Number of outliers removed from {col}: {num_outliers}")
    return test

# %% [markdown]
# > **Explanation**:
# I am using the observations from the describe performed previously to take note of which columns need outlier removal. Below is copied and pasted from before.
# - Noticeable outliers: price, bedroom, bathroom, sqft_living (REMOVED), sqft_lot, sqft_above, sqft_basement (REMOVED), sqft_living15, sqft_lot15 (REMOVED)
# >- High std: price, sqft_living (REMOVED), sqft_loft, sqft_above (REMOVED), sqft_basement (REMOVED), yr_built (more categorical), yr_renovated (more categorical), zipcode (categorical), sqft_living15, sqft_lot15

# %%
test = IQR_removal('bedrooms', test)
# Out:
# 1.0
# (19757, 62)
# Number of outliers removed from bedrooms: 454

# %%
test = IQR_removal('bathrooms', test)
# Out:
# 1.0
# (19691, 62)
# Number of outliers removed from bathrooms: 66

# %%
test = IQR_removal('sqft_lot', test)
# Out:
# 5282.0
# (17553, 62)
# Number of outliers removed from sqft_lot: 2138

# %%
test = IQR_removal('sqft_above', test)
# Out:
# 840.0
# (17058, 62)
# Number of outliers removed from sqft_above: 495

# %%
#Made numbers worse
#test = IQR_removal('view', test)

# %%
#No positive impact. Leaving in.
#test = IQR_removal('yr_built', test)

# %%
#made multicollinearity worse
#test = IQR_removal('yr_renovated', test)

# %%
test = IQR_removal('sqft_living15', test)
# Out:
# 710.0
# (16845, 62)
# Number of outliers removed from sqft_living15: 213

# %% [markdown]
# ### Visuals for Non-Technical Presentation

# %%
sns.barplot(x = test.bathrooms.round(2), y = test.price, color = 'g').set_title("Number of Bathrooms");

# %%
sns.barplot(x = test.bedrooms.round(2), y = test.price, color = 'g').set_title("Number of Bedrooms");

# %%
joint_graphs(test, 'grade', target = 'price')

# %%
sns.barplot(x = test.grade.round(2), y = test.price, color = 'g').set_title("Grade of Home");

# %%
joint_graphs(test, 'view', target = 'price')

# %%
sns.barplot(x = test.view.round(2), y = test.price, color = 'g').set_title("Views");

# %%
joint_graphs(test, 'waterfront', target = 'price')

# %%
sns.barplot(x = test.waterfront, y = test.price, color = 'g').set_title("Waterfront Housing");

# %% [markdown]
# # Model

# %% [markdown]
# ### FIfth OLS Regression Analysis

# %% [markdown]
# Between the fourth and fifth model I created a function using IQR to take care of outliers in the dataset.

# %%
features = '+'.join(test.drop(columns= 'price').columns)
features
# Out:
# 'bedrooms+bathrooms+sqft_lot+floors+waterfront+view+grade+sqft_above+yr_built+yr_renovated+lat+sqft_living15+zipcode_98002+zipcode_98004+zipcode_98005+zipcode_98006+zipcode_98007+zipcode_98008+zipcode_98010+zipcode_98022+zipcode_98023+zipcode_98024+zipcode_98027+zipcode_98029+zipcode_98033+zipcode_98034+zipcode_98038+zipcode_98039+zipcode_98040+zipcode_98045+zipcode_98052+zipcode_98053+zipcode_98056+zipcode_98059+zipcode_98065+zipcode_98072+zipcode_98074+zipcode_98075+zipcode_98102+zipcode_98103+zipcode_98105+zipcode_98106+zipcode_98107+zipcode_98108+zipcode_98109+zipcode_98112+zipcode_98115+zipcode_98116+zipcode_98117+zipcode_98118+zipcode_98119+zipcode_98122+zipcode_98125+zipcode_98126+zipcode_98133+zipcode_98136+zipcode_98144+zipcode_98146+zipcode_98168+zipcode_98177+zipcode_98199'

# %%
formula = target + '~' + features
model = smf.ols(formula, test).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.812
# Model:                            OLS   Adj. R-squared:                  0.811
# Method:                 Least Squares   F-statistic:                     1185.
# Date:                Tue, 08 Sep 2020   Prob (F-statistic):               0.00
# Time:                        18:54:04   Log-Likelihood:            -2.1480e+05
# No. Observations:               16845   AIC:                         4.297e+05
# Df Residuals:                   16783   BIC:                         4.302e+05
# Df Model:                          61
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %% [markdown]
# > **Dropping Price Outliers**:
# - multicollinearity dropped to 2.43e+07
# - R2 .796
#
# >**Removing Bedrooms Outliers**:
# - multi = 2.41e+07
# - R2 .798
#
# > **Removing Sqft_lot Outliers**:
# - multi = 5.00e+06
# - R2 = .807
#
# >**Removing Bathroom Outliers**:
# - multi =4.88e+06
# - R2 = .793
#
# > **Removing View Outliers**:
# - multi = 1.09e+16
# - R2 = .789
# - Made numbers worse therefore leaving in data.
#
# >**Removing Yr_Built Outliers**
# - multi = 4.90e+06
# - R2 = .793
# - No positive impact. Leaving in data.
#
# >**Removing Sqft_Living Outliers**
# - multi = 4.87e+06
# - R2 = .786
#
#
# >**Ending OLS Model**:
# - multi = 5.00e+06
# - R2 = .812
# - Need to remove a pval

# %%
create_visuals(test[target], model)

# %% [markdown]
# ### Question Two Answer:

# %% [markdown]
# **Question**: Does removing outliers impact my model?
#
# > **Answer:** When I first removed all the outliers in the dataset I was left with hardly anything to work with. (about 4000 rows) When I went back and only removed the outliers for price my R2 value rose and my multicollinearity dropped. This shows that removing outliers does have an impact on models and it is in the hands of the data scientist to make the correct choices.

# %%
p_val_removal(test, model)

# %%
#Recheck for any multicollinearity
X = test.drop('price', axis=1)
X = sm.add_constant(X)
X.shape
# Out:
# (16845, 61)

# %%
vif = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]

# %%
vif_results = pd.Series(dict(zip(X.columns, vif)))
vif_results
# Out:
# const            354152.674071
# bedrooms              1.568318
# bathrooms             2.396342
# sqft_lot              2.064022
# floors                2.664012
#                      ...
# zipcode_98136         1.116831
# zipcode_98144         1.205765
# zipcode_98146         1.058247
# zipcode_98177         1.160126
# zipcode_98199         1.195312
# Length: 61, dtype: float64

# %%
#no multicollinearity present
threshold = 6
bad_vif2 = list(vif_results[vif_results>threshold].index)
if 'const' in bad_vif2:
    bad_vif2.remove('const') 
bad_vif2
# Out:
# []

# %%
test.describe()
# Out:
#               price      bedrooms  ...  zipcode_98177  zipcode_98199
# count  1.684500e+04  16845.000000  ...   16845.000000   16845.000000
# mean   4.524882e+05      3.261146  ...       0.011398       0.015257
# std    1.924151e+05      0.779251  ...       0.106155       0.122576
# min    7.800000e+04      2.000000  ...       0.000000       0.000000
# 25%    3.050000e+05      3.000000  ...       0.000000       0.000000
# 50%    4.175000e+05      3.000000  ...       0.000000       0.000000
# 75%    5.650000e+05      4.000000  ...       0.000000       0.000000
# max    1.120000e+06      5.000000  ...       1.000000       1.000000
#
# [8 rows x 61 columns]

# %% [markdown]
# ### Sixth OLS Regression Analysis

# %% [markdown]
# Between the fifth and sixth OLS I rechecked for high p-values and multicollinearity using VIF.

# %%
features = '+'.join(test.drop(columns= 'price').columns)
features
# Out:
# 'bedrooms+bathrooms+sqft_lot+floors+waterfront+view+grade+sqft_above+yr_built+yr_renovated+lat+sqft_living15+zipcode_98002+zipcode_98004+zipcode_98005+zipcode_98006+zipcode_98007+zipcode_98008+zipcode_98010+zipcode_98022+zipcode_98023+zipcode_98024+zipcode_98027+zipcode_98029+zipcode_98033+zipcode_98034+zipcode_98038+zipcode_98039+zipcode_98040+zipcode_98045+zipcode_98052+zipcode_98053+zipcode_98056+zipcode_98059+zipcode_98065+zipcode_98072+zipcode_98074+zipcode_98075+zipcode_98102+zipcode_98103+zipcode_98105+zipcode_98106+zipcode_98107+zipcode_98108+zipcode_98109+zipcode_98112+zipcode_98115+zipcode_98116+zipcode_98117+zipcode_98118+zipcode_98119+zipcode_98122+zipcode_98125+zipcode_98126+zipcode_98133+zipcode_98136+zipcode_98144+zipcode_98146+zipcode_98177+zipcode_98199'

# %%
formula = target + '~' + features
model = smf.ols(formula, test).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.812
# Model:                            OLS   Adj. R-squared:                  0.811
# Method:                 Least Squares   F-statistic:                     1205.
# Date:                Tue, 08 Sep 2020   Prob (F-statistic):               0.00
# Time:                        18:54:10   Log-Likelihood:            -2.1480e+05
# No. Observations:               16845   AIC:                         4.297e+05
# Df Residuals:                   16784   BIC:                         4.302e+05
# Df Model:                          60
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %% [markdown]
# > **Observations**:
# - R2 stayed the same .812
# - Pvalues taken care of
# - Multicollinearity stayed at 5.00e+06

# %%
create_visuals(test[target], model)

# %% [markdown]
# **Reflection**:
# > QQplot is still not where I would like it to be. I had tried to remove another layer of outliers on the price column and a couple additional columns and no change was made to the QQPlot. Below I rechecked for multicollinearity and came up with no bad columns. I will try a log transformation to see if it improves the QQPlot at all.

# %% [markdown]
# ### Log Transformation

# %%
test.columns
# Out:
# Index(['price', 'bedrooms', 'bathrooms', 'sqft_lot', 'floors', 'waterfront',
#        'view', 'grade', 'sqft_above', 'yr_built', 'yr_renovated', 'lat',
#        'sqft_living15', 'zipcode_98002', 'zipcode_98004', 'zipcode_98005',
#        'zipcode_98006', 'zipcode_98007', 'zipcode_98008', 'zipcode_98010',
#        'zipcode_98022', 'zipcode_98023', 'zipcode_98024', 'zipcode_98027',
#        'zipcode_98029', 'zipcode_98033', 'zipcode_98034', 'zipcode_98038',
#        'zipcode_98039', 'zipcode_98040', 'zipcode_98045', 'zipcode_98052',
#        'zipcode_98053', 'zipcode_98056', 'zipcode_98059', 'zipcode_98065',
#        'zipcode_98072', 'zipcode_98074', 'zipcode_98075', 'zipcode_98102',
#        'zipcode_98103', 'zipcode_98105', 'zipcode_98106', 'zipcode_98107',
#        'zipcode_98108', 'zipcode_98109', 'zipcode_98112', 'zipcode_98115',
#        'zipcode_98116', 'zipcode_98117', 'zipcode_98118', 'zipcode_98119',
# ...

# %%
cols = ['bedrooms', 'bathrooms', 'sqft_lot', 'floors', 'waterfront',
       'view', 'grade', 'sqft_above', 'yr_built', 'yr_renovated', 'lat', 
        'sqft_living15']

# %%
pd.plotting.scatter_matrix(test[cols], figsize= (10,12));

# %%
#based on scattermatrix these columns look non_normal
non_normal = ['bedrooms', 'bathrooms', 'sqft_lot', 'floors', 'lat',
              'sqft_above', 'yr_built', 'sqft_living15', 'grade']
#for col in non_normal apply log transformation
for feat in non_normal:
    test[feat] = test[feat].map(lambda x: np.log(x))
pd.plotting.scatter_matrix(test[cols], figsize=(10,12));

# %% [markdown]
# ### Seventh OLS Regression Analysis

# %% [markdown]
# Between the sixth and seventh OLS model I completed a log transformation.

# %%
p_val_removal(test, model)

# %%
features = '+'.join(test.drop(columns= 'price').columns)
features
# Out:
# 'bedrooms+bathrooms+sqft_lot+floors+waterfront+view+grade+sqft_above+yr_built+yr_renovated+lat+sqft_living15+zipcode_98002+zipcode_98004+zipcode_98005+zipcode_98006+zipcode_98007+zipcode_98008+zipcode_98010+zipcode_98022+zipcode_98023+zipcode_98024+zipcode_98027+zipcode_98029+zipcode_98033+zipcode_98034+zipcode_98038+zipcode_98039+zipcode_98040+zipcode_98045+zipcode_98052+zipcode_98053+zipcode_98056+zipcode_98059+zipcode_98065+zipcode_98072+zipcode_98074+zipcode_98075+zipcode_98102+zipcode_98103+zipcode_98105+zipcode_98106+zipcode_98107+zipcode_98108+zipcode_98109+zipcode_98112+zipcode_98115+zipcode_98116+zipcode_98117+zipcode_98118+zipcode_98119+zipcode_98122+zipcode_98125+zipcode_98126+zipcode_98133+zipcode_98136+zipcode_98144+zipcode_98146+zipcode_98177+zipcode_98199'

# %%
formula = target + '~' + features
model = smf.ols(formula, test).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.805
# Model:                            OLS   Adj. R-squared:                  0.804
# Method:                 Least Squares   F-statistic:                     1152.
# Date:                Tue, 08 Sep 2020   Prob (F-statistic):               0.00
# Time:                        18:55:28   Log-Likelihood:            -2.1511e+05
# No. Observations:               16845   AIC:                         4.303e+05
# Df Residuals:                   16784   BIC:                         4.308e+05
# Df Model:                          60
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %% [markdown]
# > **Observations**:
# - R2 dropped to .805
# - Pvalues are still good
# - Multicollinearity dropped to 8.58e+05

# %%
create_visuals(test[target], model)

# %% [markdown]
# ### Question Three Answer:

# %% [markdown]
# **Question**: Does log transformation improve the overall model?
#
# >**Answer**: By observing the sixth and seventh OLS Regression Analysis, we are able to see that log transformation improved the R^2 value and dropped the multicollinearity. This shows that log transformation can impact the overall model positively.

# %% [markdown]
# ###  Eighth Regression Analysis

# %% [markdown]
# In the eighth model I tried to drop additional columns to improve Regression.

# %%
p_val_removal(test, model)

# %%
test = test.drop(columns = ['sqft_lot', 'yr_built', 'yr_renovated'])

# %%
features = '+'.join(test.drop(columns= 'price').columns)
features
# Out:
# 'bedrooms+bathrooms+floors+waterfront+view+grade+sqft_above+lat+sqft_living15+zipcode_98002+zipcode_98004+zipcode_98005+zipcode_98006+zipcode_98007+zipcode_98008+zipcode_98010+zipcode_98022+zipcode_98023+zipcode_98024+zipcode_98027+zipcode_98029+zipcode_98033+zipcode_98034+zipcode_98038+zipcode_98039+zipcode_98040+zipcode_98045+zipcode_98052+zipcode_98053+zipcode_98056+zipcode_98059+zipcode_98065+zipcode_98072+zipcode_98074+zipcode_98075+zipcode_98102+zipcode_98103+zipcode_98105+zipcode_98106+zipcode_98107+zipcode_98108+zipcode_98109+zipcode_98112+zipcode_98115+zipcode_98116+zipcode_98117+zipcode_98118+zipcode_98119+zipcode_98122+zipcode_98125+zipcode_98126+zipcode_98133+zipcode_98136+zipcode_98144+zipcode_98146+zipcode_98177+zipcode_98199'

# %%
formula = target + '~' + features
model = smf.ols(formula, test).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.792
# Model:                            OLS   Adj. R-squared:                  0.791
# Method:                 Least Squares   F-statistic:                     1122.
# Date:                Tue, 08 Sep 2020   Prob (F-statistic):               0.00
# Time:                        18:55:30   Log-Likelihood:            -2.1563e+05
# No. Observations:               16845   AIC:                         4.314e+05
# Df Residuals:                   16787   BIC:                         4.318e+05
# Df Model:                          57
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %% [markdown]
# ### Final Regression Analysis

# %% [markdown]
# Had to drop a couple of high p-values in order to create a final model.

# %%
p_val_removal(test, model)

# %%
features = '+'.join(test.drop(columns= 'price').columns)
features
# Out:
# 'bedrooms+bathrooms+floors+waterfront+view+grade+sqft_above+lat+sqft_living15+zipcode_98002+zipcode_98004+zipcode_98005+zipcode_98006+zipcode_98007+zipcode_98008+zipcode_98010+zipcode_98022+zipcode_98024+zipcode_98027+zipcode_98029+zipcode_98033+zipcode_98034+zipcode_98038+zipcode_98039+zipcode_98040+zipcode_98045+zipcode_98052+zipcode_98053+zipcode_98056+zipcode_98059+zipcode_98065+zipcode_98072+zipcode_98074+zipcode_98075+zipcode_98102+zipcode_98103+zipcode_98105+zipcode_98106+zipcode_98107+zipcode_98108+zipcode_98109+zipcode_98112+zipcode_98115+zipcode_98116+zipcode_98117+zipcode_98118+zipcode_98119+zipcode_98122+zipcode_98125+zipcode_98126+zipcode_98133+zipcode_98136+zipcode_98144+zipcode_98146+zipcode_98177+zipcode_98199'

# %%
formula = target + '~' + features
model = smf.ols(formula, test).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.792
# Model:                            OLS   Adj. R-squared:                  0.791
# Method:                 Least Squares   F-statistic:                     1142.
# Date:                Tue, 08 Sep 2020   Prob (F-statistic):               0.00
# Time:                        18:55:49   Log-Likelihood:            -2.1564e+05
# No. Observations:               16845   AIC:                         4.314e+05
# Df Residuals:                   16788   BIC:                         4.318e+05
# Df Model:                          56
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %% [markdown]
# >**FINAL MODEL EXPLANATION**:
# We can see in the final model that all of our p-values have been taken care of and are all less than .05. The R squared is .792 which represents the percentage of variance in the dependent variable that the independent variables explain. This means that the model explains the variation of price in response to the other columns 79% of the time. Looking at multicollinearity we can see that it is still slightly present. Our last model ended with a multicollinearity of 2.51e+04. Any multicollinearity with a VIF of 6 or above was dropped from our data set in order to avoid problems. Looking at skewness we have a number of .532. This represents a slightly moderate skew, but is very close to being symmetric. Our kurtosis is 5.176 which means it is leptokurtic skew. I have done all that I can think of to improve these numbers throughout the jupyter notebook.

# %%
create_visuals(test[target], model)

# %%
# test = test.drop(columns = ['zipcode_98002', 'zipcode_98004', 'zipcode_98005',
#                          'zipcode_98006', 'zipcode_98007', 'zipcode_98008',
#                          'zipcode_98010', 'zipcode_98022', 'zipcode_98024',
#                          'zipcode_98027', 'zipcode_98029', 'zipcode_98033',
#                          'zipcode_98034', 'zipcode_98038', 'zipcode_98039',
#                          'zipcode_98040', 'zipcode_98045', 'zipcode_98052',
#                          'zipcode_98053', 'zipcode_98056', 'zipcode_98059',
#                          'zipcode_98065', 'zipcode_98074', 'zipcode_98075',
#                          'zipcode_98102', 'zipcode_98103', 'zipcode_98105',
#                          'zipcode_98106', 'zipcode_98107', 'zipcode_98108',
#                          'zipcode_98109', 'zipcode_98112', 'zipcode_98115',
#                          'zipcode_98116', 'zipcode_98117','zipcode_98118',
#                          'zipcode_98119', 'zipcode_98122', 'zipcode_98125',
#                          'zipcode_98126', 'zipcode_98133', 'zipcode_98136',
#                          'zipcode_98144', 'zipcode_98146', 'zipcode_98177',
#                          'zipcode_98199'])

# %%
# features = '+'.join(test.drop(columns= 'price').columns)
# features

# %%
# formula = target + '~' + features
# model = smf.ols(formula, test).fit()
# model.summary()

# %%
#create_visuals(test[target])

# %% [markdown]
# >**Explanation**: Above I tried testing other rows to see if I could do anything else to improve my model. Dropping additional columns did not help the overall model.

# %% [markdown]
# ## Regression Model Validation

# %%
#import libraries
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
#define final features(X) & target(y)
X = test.drop(columns= 'price')
y = test.price

# %%
#perform train-test-split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
#print lengths of each
print(len(X_train), len(X_test), len(y_train), len(y_test))
# Out:
# 13476 3369 13476 3369

# %%
linreg = LinearRegression()
linreg.fit(X_train, y_train)

y_hat_train = linreg.predict(X_train)
y_hat_test = linreg.predict(X_test)

# %%
train_residuals = y_hat_train - y_train
test_residuals = y_hat_test - y_test

# %%
#calculate MSE for training and test sets
train_mse = mean_squared_error(y_train, y_hat_train)
test_mse = mean_squared_error(y_test, y_hat_test)
print('Train Mean Squarred Error:', train_mse)
print('Test Mean Squarred Error:', test_mse)
print('Std Deviation Target:', test.price.std())
# Out:
# Train Mean Squarred Error: 7711738905.211728
# Test Mean Squarred Error: 7674625121.344055
# Std Deviation Target: 192415.13950339542

# %% [markdown]
# **Comparing R^2 Between Train and Test Sets**

# %%
df_train, df_test = train_test_split(test, test_size=.25)

# %%
df_train.shape, df_test.shape
# Out:
# ((12633, 57), (4212, 57))

# %% [markdown]
# Next do model summary using training summary

# %%
features = '+'.join(df_train.drop(columns= 'price').columns)
features
# Out:
# 'bedrooms+bathrooms+floors+waterfront+view+grade+sqft_above+lat+sqft_living15+zipcode_98002+zipcode_98004+zipcode_98005+zipcode_98006+zipcode_98007+zipcode_98008+zipcode_98010+zipcode_98022+zipcode_98024+zipcode_98027+zipcode_98029+zipcode_98033+zipcode_98034+zipcode_98038+zipcode_98039+zipcode_98040+zipcode_98045+zipcode_98052+zipcode_98053+zipcode_98056+zipcode_98059+zipcode_98065+zipcode_98072+zipcode_98074+zipcode_98075+zipcode_98102+zipcode_98103+zipcode_98105+zipcode_98106+zipcode_98107+zipcode_98108+zipcode_98109+zipcode_98112+zipcode_98115+zipcode_98116+zipcode_98117+zipcode_98118+zipcode_98119+zipcode_98122+zipcode_98125+zipcode_98126+zipcode_98133+zipcode_98136+zipcode_98144+zipcode_98146+zipcode_98177+zipcode_98199'

# %%
formula = target + '~' + features
model = smf.ols(formula, df_train).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.788
# Model:                            OLS   Adj. R-squared:                  0.787
# Method:                 Least Squares   F-statistic:                     833.2
# Date:                Tue, 08 Sep 2020   Prob (F-statistic):               0.00
# Time:                        18:55:52   Log-Likelihood:            -1.6179e+05
# No. Observations:               12633   AIC:                         3.237e+05
# Df Residuals:                   12576   BIC:                         3.241e+05
# Df Model:                          56
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %% [markdown]
# >**Observations**:
# - R2 is .001 higher than mine.
# - Test multicollinearity number is slightly lower than mine. 2.63e+04 vs 2.62e+04

# %%
y_train_pred = model.predict(df_train)
y_train_pred
# Out:
# 8382     334605.833957
# 5814     577293.873152
# 7116     614803.403477
# 13937    839072.792040
# 16507    266039.938914
#              ...
# 10509    310404.235534
# 9511     502674.483146
# 2238     274360.185710
# 5186     355312.970457
# 2901     550426.726233
# Length: 12633, dtype: float64

# %%
y_test_pred = model.predict(df_test)
y_test_pred
# Out:
# 12343    378399.661106
# 8419     655127.303914
# 5761     267557.394600
# 6087     454852.070014
# 20078    567825.654478
#              ...
# 2679     125770.120215
# 11999    484216.186098
# 5960     621714.315385
# 20963    427292.482436
# 14478    328556.440340
# Length: 4212, dtype: float64

# %%
r2_train = r2_score(df_train['price'], y_train_pred)
r2_test = r2_score(df_test['price'], y_test_pred)
#want close scores,should be same as models above

print(f"Training Score: {r2_train}")
print(f"Test Score: {r2_test}")
# Out:
# Training Score: 0.787689129735058
# Test Score: 0.8035061032002323

# %% [markdown]
# > **Observations**:
# - Numbers should be close to the same. There is a .79% difference between the train and test R^2

# %%
create_visuals(df_train[target], model)

# %% [markdown]
# # Interpret

# %% [markdown]
# ### Final Model Explanation

# %%
def color_negative(val):
    color = "red" if val < 0 else 'black'
    return 'color: %s' % color

# %%
coeffs = model.params.sort_values(ascending=False)
#if you increase by one thats the increase in selling point. 
coeffs.sort_index().to_frame('Coefficients').style.applymap(color_negative)
# Out:
# <style  type="text/css" >
#     #T_73af45a6_f226_11ea_800c_d0817a9db666row0_col0 {
#             color:  red;
#         }    #T_73af45a6_f226_11ea_800c_d0817a9db666row1_col0 {
#             color:  black;
#         }    #T_73af45a6_f226_11ea_800c_d0817a9db666row2_col0 {
#             color:  black;
#         }    #T_73af45a6_f226_11ea_800c_d0817a9db666row3_col0 {
#             color:  red;
#         }    #T_73af45a6_f226_11ea_800c_d0817a9db666row4_col0 {
#             color:  black;
#         }    #T_73af45a6_f226_11ea_800c_d0817a9db666row5_col0 {
#             color:  black;
#         }    #T_73af45a6_f226_11ea_800c_d0817a9db666row6_col0 {
#             color:  black;
#         }    #T_73af45a6_f226_11ea_800c_d0817a9db666row7_col0 {
#             color:  black;
#         }    #T_73af45a6_f226_11ea_800c_d0817a9db666row8_col0 {
#             color:  black;
#         }    #T_73af45a6_f226_11ea_800c_d0817a9db666row9_col0 {
#             color:  black;
# ...

# %% [markdown]
# **Summary**:
# >The coefficients show the relationship between each independent variable and the dependent variable of price. The higher the number the greater the positive relationship between the two. Since I performed a log transformation on bedrooms, bathrooms, sqft_lot, floors, lat, sqft_above, yr_built, sqft_living15, grade we will need to divide these columns by 100 to see how the 1% increase or decrease in these independent columns impact price. Some observations are listed below:
# - **Bedroom** 33,444/100 = 334.44. A 1% increase of bedrooms increases the price by 334.44 dollars. Therefore adding more bedrooms to your house increases value.
# - **Bathroom** A 1% increase in bathrooms causes a 374.88 dollar increase in price.
# - **Grade** Grade is the column that caused the largest increase to the dependent variable of price. This shows that houses built with better materials and are on the higher grade end will sell for much higher prices than lower ones. 2,635.13 dollars for every 1% increase.
# - **Waterfront** Waterfront was an item that I did not log transform. Thus living on waterfront increases the price of the house on average by 224995 dollars. This is usually out of the homeowners control, but something to consider when buying houses.
# - **Sqft_above** 1655.68 increase in price per 1% sqft_above. Sqft_above is the square footage of the house apart from the basement.
# - **Sqft_living15** 802.39 increase in price per 1% sqft_living15. Sqft_living15 is define as Living room area in 2015.
# - **View** View was not log transformed therefore increasing how many times the house was viewed before selling increases the homes price by 45796 dollars.

# %% [markdown]
# # Conclusions & Recommendations

# %% [markdown]
# ### Use High Grade Material When Building Your Home

# %%
joint_graphs(test, 'grade', target = 'price')

# %%
sns.barplot(x = test.grade.round(2), y = test.price, color = 'g').set_title("Grade vs. Price");

# %%
#testing to see views with grade.
sns.barplot(x = test.grade.round(2), y = test.price, hue = test.view).set_title("Grade/View of Property");

# %% [markdown]
# >**Explanation**: We can see there is a positive linear relationship between grade and price. The better materials used to build and/or remodel the house equals a higher price point for the overall sale of the home.

# %% [markdown]
# ### Increase number of bedrooms and bathrooms

# %%
joint_graphs(test, 'bedrooms', target = 'price')

# %%
joint_graphs(test, 'bathrooms', target = 'price')

# %%
sns.barplot(x = test.bedrooms.round(2), y = test.price).set_title("Number of Bedrooms");

# %%
sns.barplot(x = test.bathrooms.round(2), y = test.price, color = 'g').set_title("Number of Bathrooms");

# %% [markdown]
# >**Explanation**:
# As we can see in the above graphs adding bedrooms and bathrooms to a home increases the value of the home. We can see a positive linear relationship between bedrooms/bathrooms and price. *reminder I log transformed so the x-axis does not represent the exact number.*

# %% [markdown]
# ### Purchase a house that is waterfront

# %%
joint_graphs(test, 'waterfront', target = 'price')

# %%
sns.barplot(x = test.waterfront, y = test.price).set_title("Waterfront Property");

# %% [markdown]
# >**Explanation**:
# As we can see in the above graphs having a house that is waterfront increases the value of the home. We can see a positive linear relationship between waterfront and price.

# %% [markdown]
# ### Try to have at least 3 viewings before selling the house

# %%
joint_graphs(test, 'view', target = 'price')

# %%
sns.barplot(x = test.view, y = test.price).set_title("Views of Property");

# %%
#comparing views with waterfront view.
sns.barplot(x = test.view, y = test.price,hue = test.waterfront).set_title("Views of Property");

# %% [markdown]
# >**Explanation**: Based on the above graph I would recommend that the seller has at least three viewings before selling their home. This allows a greater amount of individuals to view their home which may lead to more offers. Each view increases price by 45,796 on average.

# %% [markdown]
# ### Consider location

# %%
# %%html
# <div class='tableauPlaceholder' id='viz1598550849044' style='position: relative'><noscript><a href='#'><img alt=' ' src='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Pr&#47;Pricevs_Location&#47;Sheet2&#47;1_rss.png' style='border: none' /></a></noscript><object class='tableauViz'  style='display:none;'><param name='host_url' value='https%3A%2F%2Fpublic.tableau.com%2F' /> <param name='embed_code_version' value='3' /> <param name='path' value='views&#47;Pricevs_Location&#47;Sheet2?:language=en&amp;:embed=y&amp;:display_count=y&amp;publish=yes' /> <param name='toolbar' value='yes' /><param name='static_image' value='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Pr&#47;Pricevs_Location&#47;Sheet2&#47;1.png' /> <param name='animate_transition' value='yes' /><param name='display_static_image' value='yes' /><param name='display_spinner' value='yes' /><param name='display_overlay' value='yes' /><param name='display_count' value='yes' /><param name='language' value='en' /><param name='filter' value='publish=yes' /></object></div>                <script type='text/javascript'>                    var divElement = document.getElementById('viz1598550849044');                    var vizElement = divElement.getElementsByTagName('object')[0];                    vizElement.style.width='100%';vizElement.style.height=(divElement.offsetWidth*0.75)+'px';                    var scriptElement = document.createElement('script');                    scriptElement.src = 'https://public.tableau.com/javascripts/api/viz_v1.js';                    vizElement.parentNode.insertBefore(scriptElement, vizElement);                </script>
# Out:
# <div class='tableauPlaceholder' id='viz1598550849044' style='position: relative'><noscript><a href='#'><img alt=' ' src='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Pr&#47;Pricevs_Location&#47;Sheet2&#47;1_rss.png' style='border: none' /></a></noscript><object class='tableauViz'  style='display:none;'><param name='host_url' value='https%3A%2F%2Fpublic.tableau.com%2F' /> <param name='embed_code_version' value='3' /> <param name='path' value='views&#47;Pricevs_Location&#47;Sheet2?:language=en&amp;:embed=y&amp;:display_count=y&amp;publish=yes' /> <param name='toolbar' value='yes' /><param name='static_image' value='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Pr&#47;Pricevs_Location&#47;Sheet2&#47;1.png' /> <param name='animate_transition' value='yes' /><param name='display_static_image' value='yes' /><param name='display_spinner' value='yes' /><param name='display_overlay' value='yes' /><param name='display_count' value='yes' /><param name='language' va
# ...

# %% [markdown]
# >**Explanation**:
# Looking at the map you can see that the darker green the zipcode the higher prices homes sell for. This could be do to school districts, walkability, and convinence. If I had more time to work on this project these would be data points that I would look into.

# %% [markdown]
# Thank you.
